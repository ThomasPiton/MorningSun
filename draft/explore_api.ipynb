# %% [markdown]
# # List WEBSITE_NAME Endpoints:

# %%
[
    # 
    "https://www.us-api.morningstar.com/QS-markets/chartservice/v2/timeseries",
    # 
    "https://www.morningstar.com/api/v2/stores/realtime/quotes",
    # 
    "https://www.morningstar.com/api/v2/investing-definitions/by-fields",
    # 
    "https://www.morningstar.com/api/v2/stocks/xnas/tsla/quote",
    # 
    "https://api-global.morningstar.com/sal-service/v1/stock/esgRisk/sustainability",
    # 
    "https://api-global.morningstar.com/sal-service/v1/stock/keyratios/0P0000OQN8/data"
    # 
    "https://api-global.morningstar.com/sal-service/v1/stock/operatingPerformance/v2/0P0000OQN8",
    # 
    "https://api-global.morningstar.com/sal-service/v1/stock/insiders/boardOfDirectors/0P0000OQN8/data",
    # 
    "https://api-global.morningstar.com/sal-service/v1/stock/insiders/transactionHistory/0P0000OQN8/data",
    # 
    "https://api-global.morningstar.com/sal-service/v1/stock/insiders/transactionChart/0P0000OQN8/data",
    # 
    "https://api-global.morningstar.com/sal-service/v1/stock/ownership/v1/0P0000OQN8/OwnershipData/mutualfund/20/data",
    #
    "https://api-global.morningstar.com/sal-service/v1/stock/header/v2/data/0P000000B7/securityInfo"
    # 
    "https://www.us-api.morningstar.com/sal/sal-service/stock/realTime/v3/0P000000GY/data"
    # Official endpoint from https://developer.morningstar.com/direct-web-services/documentation/api-reference/time-series/price
    "https://www.us-api.morningstar.com/ecint/v1/timeseries/price"
]
# Out:
# ['https://www.us-api.morningstar.com/QS-markets/chartservice/v2/timeseries',
#  'https://www.morningstar.com/api/v2/stores/realtime/quotes',
#  'https://www.morningstar.com/api/v2/investing-definitions/by-fields',
#  'https://api-global.morningstar.com/sal-service/v1/stock/esgRisk/sustainability',
#  '',
#  'https://api-global.morningstar.com/sal-service/v1/stock/insiders/boardOfDirectors/0P0000OQN8/data',
#  'https://api-global.morningstar.com/sal-service/v1/stock/insiders/transactionHistory/0P0000OQN8/data',
#  'https://api-global.morningstar.com/sal-service/v1/stock/insiders/transactionChart/0P0000OQN8/data',
#  'https://www.morningstar.com/api/v2/stocks/xnas/tsla/quote',
#  '']

# %% [markdown]
# ## MAPPING

# %%
MAPPING_ = []

# %% [markdown]
# ## DOCUMENTS

# %%
https://developer.morningstar.com/direct-web-services/documentation/api-reference/screener/esg-screener

# %% [markdown]
# ## API - Timeseries

# %%
"""
website_url: https://www.morningstar.com/stocks/xnas/tsla/chart
api_url: https://www.us-api.morningstar.com/QS-markets/chartservice/v2/timeseries
=>
Comments: to get timeseries data
=>
"""

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://www.us-api.morningstar.com/QS-markets/chartservice/v2/timeseries'

HEADERS = {
    'accept': 'application/json, text/plain, */*',
    'Authorization':'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik1EY3hOemRHTnpGRFJrSTRPRGswTmtaRU1FSkdOekl5TXpORFJrUTROemd6TWtOR016bEdOdyJ9.....wJCqi9o8HUh0qUnmbAEm5OCuOqfiaiXX13fZhgiZiUVLwqMeceOfgd5ifPkB1lLSkQz9Rc_Bh5SGIK_PXlcFAzYAxHeKcFz0oGjaePIeuDQpqsZ9k-fEDlOHGTQa-uACToVIriZMP6KLewckpfYrVdqL3j6qz1p2jRNLBzd_10-A3x8KHXeMk4CgMIYPIN5Qx3s9LTXELiiOZGRe2uaOeoDBOQTwbXF1PtISV_CWG8BqvHTMzvVKQbAeLM-F_qkQRGKvifRoZshKWPtCCxhaUdRBauXak6-1ahvNdOhHHRzYht-U8BY8waTmR2gkCX29zpFlIdbG4WUMAKsUZgwT5w',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}

PAYLOAD = {
    'query': '0P0000OQN8:open,high,low,close,volume,previousClose',
    'frequency': 1,
    'preAfter': False,
    'tradingDays': 1,
    'trackMarketData': '3.6.3',
    'instid': 'DOTCOM'
}

session = requests.Session()

response = session.get(URL,params=PAYLOAD, headers=HEADERS)

msg = response.json()

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Proceed Data

data = msg[0]["series"][0]["children"]

df = pd.DataFrame(data)

df["date"] = pd.to_datetime(df['date']).dt.strftime('%Y-%m-%d %H:%M:%S')

df = df[["date","open","high","low","close","volume"]]

df
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\Thomas\lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\Thomas\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\Thomas\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\Users\Thomas\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In [9], line 38
#      34 session = requests.Session()
#      36 response = session.get(URL,params=PAYLOAD, headers=HEADERS)
# ---> 38 msg = response.json()
#      40 # ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#      41 # Proceed Data
#      43 data = msg[0]["series"][0]["children"]
#
# File c:\Users\Thomas\lib\site-packages\requests\models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## API - Last News

# %%
"""
website_url: https://www.morningstar.com/stocks/xnas/tsla/news
api_url:  https://www.morningstar.com/api/v2/{stocks}/{xnas}/{tsla}/news
=>
Comments: to extract last news
=>
"""

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://www.morningstar.com/api/v2/stocks/xnas/tsla/news'

HEADERS = {
    'accept': 'application/json, text/plain, */*',
    # 'Authorization':'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik1EY3hOemRHTnpGRFJrSTRPRGswTmtaRU1FSkdOekl5TXpORFJrUTROemd6TWtOR016bEdOdyJ9.....wJCqi9o8HUh0qUnmbAEm5OCuOqfiaiXX13fZhgiZiUVLwqMeceOfgd5ifPkB1lLSkQz9Rc_Bh5SGIK_PXlcFAzYAxHeKcFz0oGjaePIeuDQpqsZ9k-fEDlOHGTQa-uACToVIriZMP6KLewckpfYrVdqL3j6qz1p2jRNLBzd_10-A3x8KHXeMk4CgMIYPIN5Qx3s9LTXELiiOZGRe2uaOeoDBOQTwbXF1PtISV_CWG8BqvHTMzvVKQbAeLM-F_qkQRGKvifRoZshKWPtCCxhaUdRBauXak6-1ahvNdOhHHRzYht-U8BY8waTmR2gkCX29zpFlIdbG4WUMAKsUZgwT5w',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}



session = requests.Session()

response = session.get(URL, headers=HEADERS)

msg = response.json()
df = pd.DataFrame(msg["components"]["news"]["payload"])
df
# Out:
#                 id       sourceId          sourceName   providerName  \
# 0      20240618116    marketwatch         MarketWatch      Dow Jones
# 1       2024061853    marketwatch         MarketWatch      Dow Jones
# 2     202406176081      dow-jones  Global News Select      Dow Jones
# 3      20240615268    marketwatch         MarketWatch      Dow Jones
# 4      20240615269    marketwatch         MarketWatch      Dow Jones
# 5     202406142683      dow-jones  Global News Select      Dow Jones
# 6      20240614263    marketwatch         MarketWatch      Dow Jones
# 7     202406142613      dow-jones  Global News Select      Dow Jones
# 8      20240614246    marketwatch         MarketWatch      Dow Jones
# 9   20240613016784  business-wire       Business Wire  Business Wire
# 10    202406137104      dow-jones  Global News Select      Dow Jones
# 11     20240613317    marketwatch         MarketWatch      Dow Jones
# 12    202406135049      dow-jones  Global News Select      Dow Jones
# 13    202406133164      dow-jones  Global News Select      Dow Jones
# 14     20240613228    marketwatch         MarketWatch      Dow Jones
# 15     20240612777    marketwatch         MarketWatch      Dow Jones
# 16    202406128138      dow-jones  Global News Select      Dow Jones
# 17     20240612282    marketwatch         MarketWatch      Dow Jones
# 18     20240612242    marketwatch         MarketWatch      Dow Jones
# 19    202406122899      dow-jones  Global News Select      Dow Jones
#
#                                                 title  \
# 0   EV stocks trade mostly lower in the wake of Fi...
# 1   'Long Magnificent Seven' is now one of the mos...
# 2   Tesla Sues EV-Battery-Supplier Matthews Over A...
# 3   Worried you missed the Nvidia bandwagon? Here ...
# 4   Worried you missed the Nvidia bandwagon? Here -2-
# 5   Tesla's Multibillion-Dollar Pay Package for Mu...
# 6   Elon Musk's massive pay package gets 1.8 billi...
# 7   Tesla's Multibillion-Dollar Pay Package for Mu...
# 8   Tesla's scare tactics worked to win shareholde...
# 9   Tesla Releases Results of 2024 Annual Meeting ...
# 10  Trending: Elon Musk Says Preliminary Votes Sho...
# 11  Tesla expects to raise price of Model 3 in EU ...
# 12  Tesla May Raise Model 3 Price in Europe Due to...
# 13  Tesla Expects to Raise Model 3 Price Due to EU...
# 14  'Thanks for your support!' Musk says Tesla sha...
# 15  Elon Musk's Tesla pay package gets another 'no...
# 16      Calpers to Vote Against Elon Musk Pay Package
# 17  Tesla's stock should hit $2,600 in five years,...
# 18  Stocks of Nio and BYD fall after Europe's new ...
# 19  Tesla to Replace Diesel-Electric Trains With B...
#
#                 publishedDate  \
# 0   2024-06-18T09:18:00-05:00
# 1   2024-06-18T06:26:00-05:00
# 2   2024-06-17T13:02:00-05:00
# 3   2024-06-15T06:00:00-05:00
# 4   2024-06-15T06:00:00-05:00
# 5   2024-06-14T05:46:00-05:00
# 6   2024-06-14T05:31:00-05:00
# 7   2024-06-14T05:31:00-05:00
# 8   2024-06-14T04:46:00-05:00
# 9   2024-06-13T22:10:00-05:00
# 10  2024-06-13T13:31:00-05:00
# 11  2024-06-13T09:08:00-05:00
# 12  2024-06-13T08:47:00-05:00
# 13  2024-06-13T06:03:00-05:00
# 14  2024-06-13T03:45:00-05:00
# 15  2024-06-12T16:15:00-05:00
# 16  2024-06-12T15:45:00-05:00
# 17  2024-06-12T10:32:00-05:00
# 18  2024-06-12T08:07:00-05:00
# 19  2024-06-12T06:01:00-05:00
#
#                                            securities
# 0   [{'name': 'BYD Co Ltd Class H', 'performanceID...
# 1   [{'name': 'Alphabet Inc Class C', 'performance...
# 2   [{'name': 'Matthews International Corp Class A...
# 3   [{'name': 'Advanced Micro Devices Inc', 'perfo...
# 4   [{'name': 'Advanced Micro Devices Inc', 'perfo...
# 5   [{'name': 'Tesla Inc', 'performanceID': '0P000...
# 6   [{'name': 'Tesla Inc', 'performanceID': '0P000...
# 7   [{'name': 'Tesla Inc', 'performanceID': '0P000...
# 8   [{'name': 'Tesla Inc', 'performanceID': '0P000...
# 9   [{'name': 'Tesla Inc', 'performanceID': '0P000...
# 10  [{'name': 'Tesla Inc', 'performanceID': '0P000...
# 11  [{'name': 'Tesla Inc', 'performanceID': '0P000...
# 12  [{'name': 'Tesla Inc', 'performanceID': '0P000...
# 13  [{'name': 'Tesla Inc', 'performanceID': '0P000...
# 14  [{'name': 'Tesla Inc', 'performanceID': '0P000...
# 15  [{'name': 'Tesla Inc', 'performanceID': '0P000...
# 16  [{'name': 'Tesla Inc', 'performanceID': '0P000...
# 17  [{'name': 'ARK Innovation ETF', 'performanceID...
# 18  [{'name': 'BYD Co Ltd Class H', 'performanceID...
# 19  [{'name': 'Siemens AG', 'performanceID': '0P00...

# %% [markdown]
# ## API - Sustainability

# %%
"""
website_url: https://www.morningstar.com/stocks/xnas/tsla/sustainability
api_url: https://api-global.morningstar.com/sal-service/v1/{stock}/esgRisk/sustainability/{0P0000OQN8}/data 
=>
Comments: ATTENTION NEED TO FIND A METHOD TO GET THE APIKEY !!
=>
"""
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://api-global.morningstar.com/sal-service/v1/stock/esgRisk/sustainability/0P0000OQN8/data'

HEADERS = {
    'Accept':'*/*',
    'Accept-Encoding':    'gzip, deflate, br, zstd',
    'Accept-Language':    'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'Apikey':    'lstzFDEOhfFNMLikKa0am9mgEKLBl49T',
    'Origin':    'https://www.morningstar.com',
    'Priority':    'u=1, i',
    'Referer':    'https://www.morningstar.com/stocks/xnas/tsla/sustainability',
    'Sec-Ch-Ua':    '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
    'Sec-Ch-Ua-Mobile':    '?0',
    'Sec-Ch-Ua-Platform':    "Windows",
    'Sec-Fetch-Dest':    'empty',
    'Sec-Fetch-Mode':    'cors',
    'Sec-Fetch-Site':    'same-site',
    'User-Agent':    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}

PAYLOAD = {
    'languageId': 'en',
    'locale': 'en',
    'clientId': 'MDC',
    'component': 'sal-eqsv-risk-rating-breakdown',
    'version': '4.30.0'
}

session = requests.Session()

response = session.get(URL,params=PAYLOAD, headers=HEADERS)

msg = response.json()

df = pd.DataFrame(msg).iloc[0:1].transpose().reset_index().rename(columns={"index":"variable",0:"value"})

df
# Out:
#                        variable  \
# 0              controllableRisk
# 1                controlledRisk
# 2          companyExposureScore
# 3                 neglectedRisk
# 4                  esgRiskScore
# 5             controlledRiskPer
# 6              neglectedRiskPer
# 7            uncontrollableRisk
# 8               esgRiskCategory
# 9       companyExposureCategory
# 10                     asOfDate
# 11       overallManagementScore
# 12    overallManagementCategory
# 13                  companyName
# 14     subindustryExposureScore
# 15  subindustryExposureCategory
# 16                        peers
#
#                                                 value
# 0                                              39.835
# 1                                             16.9219
# 2                                               41.65
# 3                                             22.9131
# 4                                             24.7281
# 5                                               42.48
# 6                                               57.52
# 7                                               1.815
# 8                                              Medium
# 9                                              Medium
# 10                            2024-06-05T05:00:00.000
# 11                                            42.4799
# 12                                            Average
# 13                                          Tesla Inc
# 14                                               48.0
# 15                                             Medium
# 16  {'controllableRisk': 48.74, 'controlledRisk': ...

# %% [markdown]
# ## API - Token

# %%
"""
website_url: 
api_url:  
=>
Comments:
=>
"""

import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://www.morningstar.com/api/v2/stores/maas/token'

HEADERS = {
    'accept': 'application/json, text/plain, */*',
    # 'Authorization':'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik1EY3hOemRHTnpGRFJrSTRPRGswTmtaRU1FSkdOekl5TXpORFJrUTROemd6TWtOR016bEdOdyJ9.....wJCqi9o8HUh0qUnmbAEm5OCuOqfiaiXX13fZhgiZiUVLwqMeceOfgd5ifPkB1lLSkQz9Rc_Bh5SGIK_PXlcFAzYAxHeKcFz0oGjaePIeuDQpqsZ9k-fEDlOHGTQa-uACToVIriZMP6KLewckpfYrVdqL3j6qz1p2jRNLBzd_10-A3x8KHXeMk4CgMIYPIN5Qx3s9LTXELiiOZGRe2uaOeoDBOQTwbXF1PtISV_CWG8BqvHTMzvVKQbAeLM-F_qkQRGKvifRoZshKWPtCCxhaUdRBauXak6-1ahvNdOhHHRzYht-U8BY8waTmR2gkCX29zpFlIdbG4WUMAKsUZgwT5w',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}

session = requests.Session()

response = session.get(URL, headers=HEADERS)

response.text
# Out:
# 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik1EY3hOemRHTnpGRFJrSTRPRGswTmtaRU1FSkdOekl5TXpORFJrUTROemd6TWtOR016bEdOdyJ9.....e-UOrvsAyc86OEP3Pwwz8c2ncwQX2oBiTq30301qFvT7UnKIYBq0JKNuMEzOORtRdeoLcT4Qn1iNIMsQHr6hRJRXUlE9aUfep9JOSLFo6J3ivrWNo8EeAYyeXCJAIldWDImlb5j-Ue1SXAMt1LzQuC3LmgL3ONHglxruydKnNx3X5pTVaQxnVFwd5Ob3ay8gaztJc04k25gwoFKziG-3SgEZ8DEHbCWAXJXLN7iQRz3ed1qhlnyl6hHisXpIbrziIAWUSAt7GT72nN6ihPKpzqoUGu4cT0fq4Nhpc1iOL73jHHNWQMWVA1pq3lNsG4cp_m5EeJXh0sq46sKjzLowbg'

# %% [markdown]
# ## API - VALUATION

# %%
"""
website_url:  https://www.morningstar.com/stocks/xnas/tsla/valuation
api_url:  https://api-global.morningstar.com/sal-service/v1/stock/keyratios/0P0000OQN8/data
=>
Comments:
=>
"""

#Code
import requests
import pandas as pd

# Set the URL you want to scrape from
URL = 'https://api-global.morningstar.com/sal-service/v1/stock/keyratios/0P0000OQN8/data'

HEADERS = {
    'Accept':'*/*',
    'Accept-Encoding':    'gzip, deflate, br, zstd',
    'Accept-Language':    'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'Apikey':    'lstzFDEOhfFNMLikKa0am9mgEKLBl49T',
    'Origin':    'https://www.morningstar.com',
    'Priority':    'u=1, i',
    'Referer':    'https://www.morningstar.com/stocks/xnas/tsla/sustainability',
    'Sec-Ch-Ua':    '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
    'Sec-Ch-Ua-Mobile':    '?0',
    'Sec-Ch-Ua-Platform':    "Windows",
    'Sec-Fetch-Dest':    'empty',
    'Sec-Fetch-Mode':    'cors',
    'Sec-Fetch-Site':    'same-site',
    'User-Agent':    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}

PAYLOAD = {
    'languageId': 'en',
    'locale': 'en',
    'clientId': 'MDC',
    'component': 'sal-key-stats-overview',
    'version': '4.30.0'
}

session = requests.Session()

response = session.get(URL,params=PAYLOAD, headers=HEADERS)
msg = response.json()
pd.DataFrame(msg)
# Out:
#                         valuationRatio growthRatio financialHealth  \
# asOfDate                    2024-06-21         NaN             NaN
# priceToBook                   9.066183         NaN             NaN
# priceToCashFlow              58.139535         NaN             NaN
# priceToSales                  6.738544         NaN             NaN
# priceToEPS                   46.813299         NaN             NaN
# reportDate                         NaN  2023-12-31      2024-03-31
# revenue                            NaN    0.453168             NaN
# operatingIncome                    NaN    0.645919             NaN
# netIncome                          NaN    1.790858             NaN
# eps                                NaN    1.721468             NaN
# quickRatio                         NaN         NaN        1.044036
# currentRatio                       NaN         NaN        1.715784
# debtToEquity                       NaN         NaN         0.15395
# returnOnAssets                     NaN         NaN             NaN
# returnOnEquity                     NaN         NaN             NaN
# returnOnInvestedCapital            NaN         NaN             NaN
# interestCoverage                   NaN         NaN             NaN
# netMargin                          NaN         NaN             NaN
# revenue3YearGrowth                 NaN         NaN             NaN
# netIncome3YearGrowth               NaN         NaN             NaN
# operatingMarginTTM                 NaN         NaN             NaN
# netMarginTTM                       NaN         NaN             NaN
# roaTTM                             NaN         NaN             NaN
# roeTTM                             NaN         NaN             NaN
# debitToEquity                      NaN         NaN             NaN
# freeCashFlow                       NaN         NaN             NaN
#
#                         efficiencyRatio profitabilityRatio  \
# asOfDate                            NaN                NaN
# priceToBook                         NaN                NaN
# priceToCashFlow                     NaN                NaN
# priceToSales                        NaN                NaN
# priceToEPS                          NaN                NaN
# reportDate                   2024-03-31         2024-03-31
# revenue                             NaN                NaN
# operatingIncome                     NaN                NaN
# netIncome                           NaN                NaN
# eps                                 NaN                NaN
# quickRatio                          NaN                NaN
# currentRatio                        NaN                NaN
# debtToEquity                        NaN                NaN
# returnOnAssets                 0.139264                NaN
# returnOnEquity                 0.242849                NaN
# returnOnInvestedCapital        0.201099                NaN
# interestCoverage                    NaN          43.985222
# netMargin                           NaN           0.144092
# revenue3YearGrowth                  NaN                NaN
# netIncome3YearGrowth                NaN                NaN
# operatingMarginTTM                  NaN                NaN
# netMarginTTM                        NaN                NaN
# roaTTM                              NaN                NaN
# roeTTM                              NaN                NaN
# debitToEquity                       NaN                NaN
# freeCashFlow                        NaN                NaN
#
#                                                          keyStatsQuoteJson
# asOfDate                                                               NaN
# priceToBook                                                            NaN
# priceToCashFlow                                                        NaN
# priceToSales                                                           NaN
# priceToEPS                                                             NaN
# reportDate                                                             NaN
# revenue                                                                NaN
# operatingIncome                                                        NaN
# netIncome                                                              NaN
# eps                                                                    NaN
# quickRatio                                                             NaN
# currentRatio                                                           NaN
# debtToEquity                                                           NaN
# returnOnAssets                                                         NaN
# returnOnEquity                                                         NaN
# returnOnInvestedCapital                                                NaN
# interestCoverage                                                       NaN
# netMargin                                                              NaN
# revenue3YearGrowth           {'stockValue': '45.3200', 'indAvg': '6.8600'}
# netIncome3YearGrowth       {'stockValue': '175.0300', 'indAvg': '30.8800'}
# operatingMarginTTM            {'stockValue': '7.8100', 'indAvg': '7.0000'}
# netMarginTTM                 {'stockValue': '14.4100', 'indAvg': '5.5900'}
# roaTTM                       {'stockValue': '13.9300', 'indAvg': '3.5200'}
# roeTTM                      {'stockValue': '24.2800', 'indAvg': '10.4300'}
# debitToEquity                 {'stockValue': '0.1048', 'indAvg': '0.6730'}
# freeCashFlow             {'cashFlowTTM': '1382000000', 'date': '2024-03...

# %% [markdown]
# ## API - VALUATION

# %%
"""
website_url: https://www.morningstar.com/stocks/xnas/tsla/performance
api_url:  https://api-global.morningstar.com/sal-service/v1/stock/operatingPerformance/v2/0P0000OQN8
=>
Comments:
=>
"""

import requests

# Set the URL you want to scrape from
URL = 'https://api-global.morningstar.com/sal-service/v1/stock/operatingPerformance/v2/0P0000OQN8'

HEADERS = {
    'Accept':'*/*',
    'Accept-Encoding':    'gzip, deflate, br, zstd',
    'Accept-Language':    'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'Apikey':    'lstzFDEOhfFNMLikKa0am9mgEKLBl49T',
    'Origin':    'https://www.morningstar.com',
    'Priority':    'u=1, i',
    'Referer':    'https://www.morningstar.com/stocks/xnas/tsla/sustainability',
    'Sec-Ch-Ua':    '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
    'Sec-Ch-Ua-Mobile':    '?0',
    'Sec-Ch-Ua-Platform':    "Windows",
    'Sec-Fetch-Dest':    'empty',
    'Sec-Fetch-Mode':    'cors',
    'Sec-Fetch-Site':    'same-site',
    'User-Agent':    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}

PAYLOAD = {
    'languageId': 'en',
    'locale': 'en',
    'clientId': 'MDC',
    'component': 'sal-oper-perf',
    'version': '4.30.0'
}

session = requests.Session()

response = session.get(URL,params=PAYLOAD, headers=HEADERS)
msg = response.json()
pd.DataFrame(msg)
# Out:
#                                               _meta  \
# responseStatus                               200700
# hint               Securities successfully returned
# performanceId                            0P0000OQN8
# reportType                                      NaN
# reportType_label                                NaN
# columnDefs                                      NaN
# columnDefs_labels                               NaN
# Collapsed                                       NaN
# Expanded                                        NaN
# indexLabel                                      NaN
# indexName                                       NaN
# asOfDate                                        NaN
# fiscalYearEndDate                               NaN
# ebitdaCurrency                                  NaN
#
#                                                             reported  \
# responseStatus                                                   NaN
# hint                                                             NaN
# performanceId                                                    NaN
# reportType                                                    Fiscal
# reportType_label                   operating.performance.report.type
# columnDefs         [2014, 2015, 2016, 2017, 2018, 2019, 2020, 202...
# columnDefs_labels  [2014, 2015, 2016, 2017, 2018, 2019, 2020, 202...
# Collapsed          {'rows': [{'label': 'Return on Assets %', 'sal...
# Expanded           {'rows': [{'label': 'Financial Leverage', 'sal...
# indexLabel                                                       NaN
# indexName                                                        NaN
# asOfDate                                                         NaN
# fiscalYearEndDate                                                NaN
# ebitdaCurrency                                                   NaN
#
#                                                             restated  \
# responseStatus                                                   NaN
# hint                                                             NaN
# performanceId                                                    NaN
# reportType                                                    Fiscal
# reportType_label                   operating.performance.report.type
# columnDefs         [2014, 2015, 2016, 2017, 2018, 2019, 2020, 202...
# columnDefs_labels  [2014, 2015, 2016, 2017, 2018, 2019, 2020, 202...
# Collapsed          {'rows': [{'label': 'Return on Assets %', 'sal...
# Expanded           {'rows': [{'label': 'Financial Leverage', 'sal...
# indexLabel                                                       NaN
# indexName                                                        NaN
# asOfDate                                                         NaN
# fiscalYearEndDate                                                NaN
# ebitdaCurrency                                                   NaN
#
#                                          footer
# responseStatus                              NaN
# hint                                        NaN
# performanceId                               NaN
# reportType                                  NaN
# reportType_label                            NaN
# columnDefs                                  NaN
# columnDefs_labels                           NaN
# Collapsed                                   NaN
# Expanded                                    NaN
# indexLabel                               Index:
# indexName          Morningstar US Market TR USD
# asOfDate                                   None
# fiscalYearEndDate                          None
# ebitdaCurrency                              USD

# %% [markdown]
# ## API - Ownership

# %%
"""
website_url: https://www.morningstar.com/stocks/xnas/tsla/ownership
api_url:  https://api-global.morningstar.com/sal-service/v1/stock/ownership/v1/0P0000OQN8/OwnershipData/mutualfund/20/data
=>
Comments:
=>
"""

import requests

# Set the URL you want to scrape from
URL = 'https://api-global.morningstar.com/sal-service/v1/stock/ownership/v1/0P0000OQN8/OwnershipData/mutualfund/20/data'

HEADERS = {
    'Accept':'*/*',
    'Accept-Encoding':    'gzip, deflate, br, zstd',
    'Accept-Language':    'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'Apikey':    'lstzFDEOhfFNMLikKa0am9mgEKLBl49T',
    'Origin':    'https://www.morningstar.com',
    'Priority':    'u=1, i',
    'Referer':    'https://www.morningstar.com/stocks/xnas/tsla/sustainability',
    'Sec-Ch-Ua':    '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
    'Sec-Ch-Ua-Mobile':    '?0',
    'Sec-Ch-Ua-Platform':    "Windows",
    'Sec-Fetch-Dest':    'empty',
    'Sec-Fetch-Mode':    'cors',
    'Sec-Fetch-Site':    'same-site',
    'User-Agent':    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}

PAYLOAD = {
    'languageId': 'en',
    'locale': 'en',
    'clientId': 'MDC',
    'component': 'sal-ownership',
    'version': '4.30.0'
}

session = requests.Session()

response = session.get(URL,params=PAYLOAD, headers=HEADERS)
msg = response.json()
pd.DataFrame(msg['rows'])
# Out:
#          secId                                    name securityType ticker  \
# 0   FOUSA00FQU        Vanguard Total Stock Mkt Idx Inv           FO  VTSMX
# 1   F000016CKS  Vanguard Institutional 500 Index Trust           CZ   None
# 2   F00001FX2E                       Performer (AFRIS)           FV   None
# 3   FEUSA00003                       Invesco QQQ Trust           FE    QQQ
# 4   F00000LZSI                      Fidelity 500 Index           FO  FXAIX
# 5   FEUSA00001                SPDR® S&P 500® ETF Trust           FE    SPY
# 6   FEUSA0000E                iShares Core S&P 500 ETF           FE    IVV
# 7   FOUSA00FQV          Vanguard Growth Index Investor           FO  VIGRX
# 8   F000013FOP   Capital Group Growth Fnd of Amer Comp           SA   None
# 9   FOUSA00D02    American Funds Growth Fund of Amer A           FO  AGTHX
# 10  FOUSA00FR3          Vanguard Institutional Index I           FO  VINIX
# 11  FEUSA00008  The Consumer Discret Sel SectSPDR® ETF           FE    XLY
# 12  FOUSA06Y9Y        State St S&P 500® Indx SL Cl III           CZ   None
# 13  FOUSA02W9R                   Baron Partners Retail           FO  BPTRX
# 14  F000013FOQ      Capital Group New Perspective Comp           SA   None
# 15  FOUSA00E5U        American Funds New Perspective A           FO  ANWPX
# 16  SAUSA004GB                Blackrock Eq Idx Fund CF           CZ   None
# 17  FEUSA0001B         iShares Russell 1000 Growth ETF           FE    IWF
# 18  SAUSA004G8                 Russell 1000 Index Fund           CZ   None
# 19  F00000NB0Q    Blackrock Russ 1000 Eq Idx Composite           SA   None
# 20        None                                    None         None   None
#
#     totalSharesHeld  totalAssets  currentShares  changeAmount  \
# 0          2.671697      1.01832       85205657         87593
# 1          2.210282      1.20041       70490244        655003
# 2          1.443958      0.07913       46050662      46050662
# 3          1.124242      2.36716       35854289         29970
# 4          1.052259      1.20038       33558617         72019
# 5          1.045282      1.11298       33336098        213720
# 6          0.903385      1.11076       28810716         -8260
# 7          0.812870      2.16021       25924027        364103
# 8          0.626924      1.27467       19993828      -2202589
# 9          0.626924      1.27416       19993828      -2202589
# 10         0.567934      1.20154       18112542       -109355
# 11         0.448584     13.64185       14306220       -128084
# 12         0.421715      1.10539       13449323         82100
# 13         0.367648     34.06812       11725000       -422500
# 14         0.333272      1.37406       10628693        100578
# 15         0.333272      1.37327       10628693        100578
# 16         0.310393      1.09630        9899057         17926
# 17         0.294910      1.84181        9405257          5307
# 18         0.263373      1.01742        8399486         39924
# 19         0.262210      1.00826        8362392        -59407
# 20        16.121135          NaN      514134629      42686699
#
#     changePercentage                     date trend starRating
# 0           0.102908  2024-04-30T00:00:00.000  _PO_          3
# 1           0.937926  2024-04-30T00:00:00.000  _PO_          4
# 2                NaN  2024-02-29T00:00:00.000  _PO_
# 3           0.083658  2024-05-31T00:00:00.000  _PO_          5
# 4           0.215068  2024-04-30T00:00:00.000  _PO_          5
# 5           0.645244  2024-05-31T00:00:00.000  _PO_          4
# 6          -0.028662  2024-05-31T00:00:00.000  _PO_          5
# 7           1.424507  2024-04-30T00:00:00.000  _PO_          4
# 8          -9.923174  2024-03-31T00:00:00.000  _PO_          3
# 9          -9.923174  2024-03-31T00:00:00.000  _PO_          3
# 10         -0.600130  2024-04-30T00:00:00.000  _PO_          5
# 11         -0.887358  2024-05-31T00:00:00.000  _PO_          4
# 12          0.614189  2024-05-31T00:00:00.000  _PO_          4
# 13         -3.478082  2024-03-31T00:00:00.000  _PO_          2
# 14          0.955328  2024-03-31T00:00:00.000  _PO_          3
# 15          0.955328  2024-03-31T00:00:00.000  _PO_          4
# 16          0.181416  2024-03-31T00:00:00.000  _PO_
# 17          0.056458  2024-05-31T00:00:00.000  _PO_          5
# 18          0.477585  2024-05-31T00:00:00.000  _PO_
# 19         -0.705396  2024-03-31T00:00:00.000  _PO_          4
# 20               NaN                     None  _PO_       None

# %% [markdown]
# ## TITLE

# %%
"""
website_url: https://www.morningstar.com/markets
api_url:  https://www.morningstar.com/api/v2/stocks/xnas/tsla/quote
=>
Comments:
=>
"""
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://www.morningstar.com/api/v2/stocks/xnas/tsla/quote'

HEADERS = {
    'accept': 'application/json, text/plain, */*',
    # 'Authorization':'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik1EY3hOemRHTnpGRFJrSTRPRGswTmtaRU1FSkdOekl5TXpORFJrUTROemd6TWtOR016bEdOdyJ9.....wJCqi9o8HUh0qUnmbAEm5OCuOqfiaiXX13fZhgiZiUVLwqMeceOfgd5ifPkB1lLSkQz9Rc_Bh5SGIK_PXlcFAzYAxHeKcFz0oGjaePIeuDQpqsZ9k-fEDlOHGTQa-uACToVIriZMP6KLewckpfYrVdqL3j6qz1p2jRNLBzd_10-A3x8KHXeMk4CgMIYPIN5Qx3s9LTXELiiOZGRe2uaOeoDBOQTwbXF1PtISV_CWG8BqvHTMzvVKQbAeLM-F_qkQRGKvifRoZshKWPtCCxhaUdRBauXak6-1ahvNdOhHHRzYht-U8BY8waTmR2gkCX29zpFlIdbG4WUMAKsUZgwT5w',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}



session = requests.Session()

response = session.get(URL, headers=HEADERS)

msg = response.json()
msg
# Out:
# {'page': {'securityID': '0P0000OQN8',
#   'performanceID': '0P0000OQN8',
#   'companyID': '0C00004EP4',
#   'universe': 'EQ',
#   'exchange': 'XNAS',
#   'ticker': 'TSLA',
#   'name': 'Tesla Inc',
#   'exchangeCountry': 'USA',
#   'investmentType': 'EQ'},
#  'pageMeta': {'title': 'Tesla (TSLA) Stock Price Quote, Value & News',
#   'description': 'See the latest Tesla Inc stock price (NASDAQ:TSLA), related news, valuation, dividends and more to help you make your investing decisions.',
#   'keywords': ''},
#  'components': {'companyReport': {'status': 401,
#    'payload': {'id': '1221573',
#     'title': 'Tesla’s Strategic Focus Shifts From Growth to Development of Affordable Vehicle and Cost Reductions',
#     'security': {'name': 'Tesla Inc',
#      'performanceID': '0P0000OQN8',
#      'securityID': '0P0000OQN8',
#      'masterPortfolioID': None,
#      'fundID': None,
#      'ticker': 'TSLA',
#      'exchange': 'XNAS',
#      'exchangeCountry': 'USA',
#      'investmentType': 'EQ',
#      'cusip': '88160R101'},
#     'coveredSecurities': [{'name': 'Tesla Inc',
#       'performanceID': '0P0000OQN8',
#       'securityID': '0P0000OQN8',
#       'masterPortfolioID': None,
#       'fundID': None,
#       'ticker': 'TSLA',
#       'exchange': 'XNAS',
#       'exchangeCountry': 'USA',
#       'investmentType': 'EQ',
#       'cusip': '88160R101'}],
#     'authors': [{'id': 'B4CHGNBBISETNZHVIA6UWV2SMU',
#       'rpsID': '2043',
#       'firstName': 'Seth',
#       'lastName': 'Goldstein',
#       'name': 'Seth Goldstein',
#       'freelancer': False,
#       'title': 'Strategist',
#       'byline': 'Seth Goldstein, CFA',
#       'shortBio': 'Seth Goldstein, CFA, is an equities strategist for Morningstar.',
#       'bio': [{'type': 'paragraph',
#         'text': "Seth Goldstein, CFA, is an equities strategist for Morningstar Research Services LLC, a wholly owned subsidiary of Morningstar, Inc. He covers agriculture, chemicals, and lithium companies in the basic materials sector and is also the chair of Morningstar's electric vehicle committee."},
#        {'type': 'paragraph',
#         'text': 'Prior to assuming the equity analyst role in 2017, Goldstein was an associate equity analyst covering the basic-materials sector. Before joining Morningstar, Goldstein was a senior financial analyst for Oasis Financial, a financial analyst for Berkshire Hathaway Energy, and a field operations supervisor for the U.S. Census Bureau. '},
#        {'type': 'paragraph',
#         'text': "Goldstein holds a bachelor's degree in journalism from Ohio University and a Master of Business Administration, with a concentration in finance, from the University of Iowa. He also holds the Chartered Financial Analyst® designation."}],
#       'image': {'src': 'https://s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg',
#        'srcset': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/mqw-nPbJEIwzOFiZmx_hcPpYZFo=/120x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 120w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/Z2S4uKzDUr61luwLn-Tag3yBZqk=/240x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 240w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/5fjXBmzjkGC_sf7g39eNoXQiEEc=/360x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 360w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/TvIsrTImrK8r2siTBGrN87fSy3c=/480x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 480w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/BiIPM1Xos-ZAx32MsH7eP8aLE2U=/640x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 640w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/VhMALuNmHfiNpBGTMKEu_QetapU=/720x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 720w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/JvBo9eRIfDj3qSNkhaUPHubCUjo=/960x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 960w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/7Lj8Bwru4tGwTgQxFKb_ntpVxPE=/1200x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1200w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/J5x8y1ZZ6Z6Ax38aPQlouQY_uHc=/1600x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1600w',
#        'variations': {'16:9': {'src': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/Cu7R97tTI1jOb8NUBN-bAvpNxJg=/2000x1125/smart/filters:no_upscale()/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg',
#          'srcset': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/2oEOmI00SYqqKKkn4iAcU2MkMfY=/120x68/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 120w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/Z_WaYwSlAWlJttW9EDZVd_nvWN4=/240x135/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 240w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/RHHCQ0h_lxms9OXXJniALhSWMCA=/360x203/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 360w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/KOZoG9iJenXpW_7yWBSG8wUuqqw=/480x270/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 480w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/vj4FBwn7luQEQniprFXvX5SYlsY=/640x360/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 640w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/TQBgDNnJ5bM43mJ1KLZi12CfMsg=/720x405/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 720w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/YaGm17gWwaOzmvtPMNvj0_YgzdQ=/960x540/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 960w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/j9bD8VS10hV9O4IUbsXj359QX8s=/1200x675/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1200w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/W8HMWrJpt8GPraqaloLqPxGTDN0=/1600x900/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1600w'},
#         '1:1': {'src': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/lgc3ot7lKgVfHaOmOsVs7aIq9ek=/2000x2000/smart/filters:no_upscale()/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg',
#          'srcset': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/LSqA1E1oFpkaZaux1qb8TERpWs8=/120x120/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 120w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/ObYT2fDeVe-cEY9s25-FZXhAvKo=/240x240/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 240w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/vcA02rGAeUIeEXyC3ij4PT5FMnM=/360x360/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 360w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/8cv5WveXzWo-42h8zPa148tsKS0=/480x480/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 480w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/xMSYqbT1M3GhABHYa_fbl_JglUA=/640x640/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 640w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/DqKyYU-rvTOYVB04DBed6dL9kbw=/720x720/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 720w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/rSuOBwyaSdOILPjNeI0waj-1y_U=/960x960/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 960w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/rb05N99AXIX_Vjsm8HPC76hQIB8=/1200x1200/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1200w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/7a53iZzYY12SNHl2C9affj8-pvU=/1600x1600/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1600w'},
#         '3:2': {'src': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/R4eal4XIEf-STPzlo5cwtBVhd3E=/2000x1333/smart/filters:no_upscale()/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg',
#          'srcset': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/TPvp3ZI22zGzeCkRPaquzOV6OQ8=/120x80/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 120w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/eDDMbJrV3WugojkpdFP4AbepBB4=/240x160/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 240w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/rreKEke91cF-CHF0aUkbtXt0shE=/360x240/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 360w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/j6SdA1yjP-lNG0EG8Co3a7Ci6_A=/480x320/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 480w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/74zmZxT3hpK5WzV4tJo0A6o7W8Y=/640x427/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 640w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/EnaitS4t6q4OvaXnkYmqHviKph0=/720x480/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 720w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/UzbP6k91ilGiGY42RiXTtuCcgB8=/960x640/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 960w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/gDrKHl49adYlcejIOrJtcdkieM8=/1200x800/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1200w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/5Gq-pxLoFHvjYNkf16JOiltKBDE=/1600x1067/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1600w'},
#         '4:3': {'src': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/xWK64FtHnSgNuiZUTlQID6nrbUg=/2000x1500/smart/filters:no_upscale()/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg',
#          'srcset': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/70BXR2Bj9uFXU0tJ1QvrOeh5Phw=/120x90/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 120w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/dtKmMJhMZj7xqn-WPip0MpoJiyQ=/240x180/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 240w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/cx3OH5BBIUzYkNfqnARlOTVqMA0=/360x270/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 360w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/QGS22tXid30XYYyI4oS8UGg4vcU=/480x360/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 480w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/zH7ZD6w7zbyxWvDUZ3speN1Gyfo=/640x480/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 640w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/-2YR2XXP_9L_lIbh24TpuQzU5tU=/720x540/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 720w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/7yWdDYaOi0Qjjoe9QEwWwKNrLds=/960x720/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 960w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/MUdZyTfCIRPfC94OqexMjnU4d1k=/1200x900/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1200w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/4ZKcdF2GwlZ7UeiLohDgoPsGqVc=/1600x1200/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1600w'}}},
#       'canonicalURL': '/people/seth-goldstein',
#       'active': True,
#       'books': [],
#       'podcasts': [],
#       'socials': [],
#       'disclosureStatements': None,
#       'jobTitle': 'Strategist'}],
#     'publishedDate': '2024-05-06',
#     'updatedDate': '2024-05-06',
#     'attachedNotes': [{'id': '1229617',
#       'title': "Tesla: Shareholders Vote for CEO Musk's 2018 Compensation Package and Reincorporation in Texas",
#       'security': {'name': 'Tesla Inc',
#        'performanceID': '0P0000OQN8',
#        'securityID': '0P0000OQN8',
#        'masterPortfolioID': None,
#        'fundID': None,
#        'ticker': 'TSLA',
#        'exchange': 'XNAS',
#        'exchangeCountry': 'USA',
#        'investmentType': 'EQ',
#        'cusip': '88160R101'},
#       'coveredSecurities': [{'name': 'Tesla Inc',
#         'performanceID': '0P0000OQN8',
#         'securityID': '0P0000OQN8',
#         'masterPortfolioID': None,
#         'fundID': None,
#         'ticker': None,
#         'exchange': None,
#         'exchangeCountry': None,
#         'investmentType': None,
#         'cusip': None}],
#       'authors': [{'id': 'B4CHGNBBISETNZHVIA6UWV2SMU',
#         'rpsID': '2043',
#         'firstName': 'Seth',
#         'lastName': 'Goldstein',
#         'name': 'Seth Goldstein',
#         'freelancer': False,
#         'title': 'Strategist',
#         'byline': 'Seth Goldstein, CFA',
#         'shortBio': 'Seth Goldstein, CFA, is an equities strategist for Morningstar.',
#         'bio': [{'type': 'paragraph',
#           'text': "Seth Goldstein, CFA, is an equities strategist for Morningstar Research Services LLC, a wholly owned subsidiary of Morningstar, Inc. He covers agriculture, chemicals, and lithium companies in the basic materials sector and is also the chair of Morningstar's electric vehicle committee."},
#          {'type': 'paragraph',
#           'text': 'Prior to assuming the equity analyst role in 2017, Goldstein was an associate equity analyst covering the basic-materials sector. Before joining Morningstar, Goldstein was a senior financial analyst for Oasis Financial, a financial analyst for Berkshire Hathaway Energy, and a field operations supervisor for the U.S. Census Bureau. '},
#          {'type': 'paragraph',
#           'text': "Goldstein holds a bachelor's degree in journalism from Ohio University and a Master of Business Administration, with a concentration in finance, from the University of Iowa. He also holds the Chartered Financial Analyst® designation."}],
#         'image': {'src': 'https://s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg',
#          'srcset': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/mqw-nPbJEIwzOFiZmx_hcPpYZFo=/120x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 120w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/Z2S4uKzDUr61luwLn-Tag3yBZqk=/240x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 240w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/5fjXBmzjkGC_sf7g39eNoXQiEEc=/360x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 360w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/TvIsrTImrK8r2siTBGrN87fSy3c=/480x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 480w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/BiIPM1Xos-ZAx32MsH7eP8aLE2U=/640x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 640w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/VhMALuNmHfiNpBGTMKEu_QetapU=/720x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 720w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/JvBo9eRIfDj3qSNkhaUPHubCUjo=/960x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 960w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/7Lj8Bwru4tGwTgQxFKb_ntpVxPE=/1200x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1200w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/J5x8y1ZZ6Z6Ax38aPQlouQY_uHc=/1600x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1600w',
#          'variations': {'16:9': {'src': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/Cu7R97tTI1jOb8NUBN-bAvpNxJg=/2000x1125/smart/filters:no_upscale()/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg',
#            'srcset': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/2oEOmI00SYqqKKkn4iAcU2MkMfY=/120x68/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 120w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/Z_WaYwSlAWlJttW9EDZVd_nvWN4=/240x135/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 240w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/RHHCQ0h_lxms9OXXJniALhSWMCA=/360x203/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 360w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/KOZoG9iJenXpW_7yWBSG8wUuqqw=/480x270/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 480w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/vj4FBwn7luQEQniprFXvX5SYlsY=/640x360/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 640w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/TQBgDNnJ5bM43mJ1KLZi12CfMsg=/720x405/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 720w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/YaGm17gWwaOzmvtPMNvj0_YgzdQ=/960x540/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 960w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/j9bD8VS10hV9O4IUbsXj359QX8s=/1200x675/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1200w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/W8HMWrJpt8GPraqaloLqPxGTDN0=/1600x900/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1600w'},
#           '1:1': {'src': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/lgc3ot7lKgVfHaOmOsVs7aIq9ek=/2000x2000/smart/filters:no_upscale()/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg',
#            'srcset': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/LSqA1E1oFpkaZaux1qb8TERpWs8=/120x120/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 120w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/ObYT2fDeVe-cEY9s25-FZXhAvKo=/240x240/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 240w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/vcA02rGAeUIeEXyC3ij4PT5FMnM=/360x360/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 360w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/8cv5WveXzWo-42h8zPa148tsKS0=/480x480/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 480w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/xMSYqbT1M3GhABHYa_fbl_JglUA=/640x640/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 640w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/DqKyYU-rvTOYVB04DBed6dL9kbw=/720x720/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 720w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/rSuOBwyaSdOILPjNeI0waj-1y_U=/960x960/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 960w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/rb05N99AXIX_Vjsm8HPC76hQIB8=/1200x1200/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1200w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/7a53iZzYY12SNHl2C9affj8-pvU=/1600x1600/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1600w'},
#           '3:2': {'src': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/R4eal4XIEf-STPzlo5cwtBVhd3E=/2000x1333/smart/filters:no_upscale()/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg',
#            'srcset': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/TPvp3ZI22zGzeCkRPaquzOV6OQ8=/120x80/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 120w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/eDDMbJrV3WugojkpdFP4AbepBB4=/240x160/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 240w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/rreKEke91cF-CHF0aUkbtXt0shE=/360x240/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 360w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/j6SdA1yjP-lNG0EG8Co3a7Ci6_A=/480x320/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 480w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/74zmZxT3hpK5WzV4tJo0A6o7W8Y=/640x427/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 640w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/EnaitS4t6q4OvaXnkYmqHviKph0=/720x480/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 720w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/UzbP6k91ilGiGY42RiXTtuCcgB8=/960x640/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 960w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/gDrKHl49adYlcejIOrJtcdkieM8=/1200x800/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1200w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/5Gq-pxLoFHvjYNkf16JOiltKBDE=/1600x1067/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1600w'},
#           '4:3': {'src': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/xWK64FtHnSgNuiZUTlQID6nrbUg=/2000x1500/smart/filters:no_upscale()/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg',
#            'srcset': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/70BXR2Bj9uFXU0tJ1QvrOeh5Phw=/120x90/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 120w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/dtKmMJhMZj7xqn-WPip0MpoJiyQ=/240x180/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 240w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/cx3OH5BBIUzYkNfqnARlOTVqMA0=/360x270/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 360w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/QGS22tXid30XYYyI4oS8UGg4vcU=/480x360/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 480w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/zH7ZD6w7zbyxWvDUZ3speN1Gyfo=/640x480/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 640w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/-2YR2XXP_9L_lIbh24TpuQzU5tU=/720x540/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 720w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/7yWdDYaOi0Qjjoe9QEwWwKNrLds=/960x720/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 960w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/MUdZyTfCIRPfC94OqexMjnU4d1k=/1200x900/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1200w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/4ZKcdF2GwlZ7UeiLohDgoPsGqVc=/1600x1200/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1600w'}}},
#         'canonicalURL': '/people/seth-goldstein',
#         'active': True,
#         'books': [],
#         'podcasts': [],
#         'socials': [],
#         'disclosureStatements': None,
#         'jobTitle': 'Strategist'}],
#       'publishedDate': '2024-06-14',
#       'updatedDate': '2024-06-14',
#       'reportType': {'id': 'stock-analyst-note', 'name': 'Stock Analyst Note'},
#       'bearsSay': [],
#       'bullsSay': [],
#       'attachedNotes': [],
#       'contentElements': [{'type': 'paragraph',
#         'text': "Tesla reported the results of its annual shareholder meeting on June 13. Shareholders voted with the board recommendations on nearly every proposal, including approving CEO Elon Musk's 2018 compensation package as well as reincorporating in the US state of Texas from Delaware. We see no reason to change our outlook for Tesla as a result of the vote. Accordingly, we maintain our $200 fair value estimate. Our narrow moat rating is also unchanged."}],
#       'sections': []},
#      {'id': '1223485',
#       'title': 'US Tariffs on Chinese EVs Do Not Change Our View of US EV Adoption',
#       'security': {'name': 'Tesla Inc',
#        'performanceID': '0P0000OQN8',
#        'securityID': '0P0000OQN8',
#        'masterPortfolioID': None,
#        'fundID': None,
#        'ticker': 'TSLA',
#        'exchange': 'XNAS',
#        'exchangeCountry': 'USA',
#        'investmentType': 'EQ',
#        'cusip': '88160R101'},
#       'coveredSecurities': [{'name': 'Lithium Americas (Argentina) Corp',
#         'performanceID': '0P0000GO1I',
#         'securityID': '0P0000GO1I',
#         'masterPortfolioID': None,
#         'fundID': None,
#         'ticker': None,
#         'exchange': None,
#         'exchangeCountry': None,
#         'investmentType': None,
#         'cusip': None},
#        {'name': 'Lithium Americas (Argentina) Corp',
#         'performanceID': '0P0000JU6Z',
#         'securityID': '0P0000JU6Z',
#         'masterPortfolioID': None,
#         'fundID': None,
#         'ticker': None,
#         'exchange': None,
#         'exchangeCountry': None,
#         'investmentType': None,
#         'cusip': None},
#        {'name': 'Tesla Inc',
#         'performanceID': '0P0000OQN8',
#         'securityID': '0P0000OQN8',
#         'masterPortfolioID': None,
#         'fundID': None,
#         'ticker': None,
#         'exchange': None,
#         'exchangeCountry': None,
#         'investmentType': None,
#         'cusip': None},
#        {'name': 'General Motors Co',
#         'performanceID': '0P0000RQZL',
#         'securityID': '0P0000RQZL',
#         'masterPortfolioID': None,
#         'fundID': None,
#         'ticker': None,
#         'exchange': None,
#         'exchangeCountry': None,
#         'investmentType': None,
#         'cusip': None},
#        {'name': 'Arcadium Lithium PLC',
#         'performanceID': '0P0001EQ9A',
#         'securityID': '0P0001EQ9A',
#         'masterPortfolioID': None,
#         'fundID': None,
#         'ticker': None,
#         'exchange': None,
#         'exchangeCountry': None,
#         'investmentType': None,
#         'cusip': None},
#        {'name': 'Lithium Americas Corp',
#         'performanceID': '0P0001ROEL',
#         'securityID': '0P0001ROEL',
#         'masterPortfolioID': None,
#         'fundID': None,
#         'ticker': None,
#         'exchange': None,
#         'exchangeCountry': None,
#         'investmentType': None,
#         'cusip': None},
#        {'name': 'Lithium Americas Corp',
#         'performanceID': '0P0001ROEN',
#         'securityID': '0P0001ROEN',
#         'masterPortfolioID': None,
#         'fundID': None,
#         'ticker': None,
#         'exchange': None,
#         'exchangeCountry': None,
#         'investmentType': None,
#         'cusip': None},
#        {'name': 'Albemarle Corp',
#         'performanceID': '0P0000008C',
#         'securityID': '0P0000008C',
#         'masterPortfolioID': None,
#         'fundID': None,
#         'ticker': None,
#         'exchange': None,
#         'exchangeCountry': None,
#         'investmentType': None,
#         'cusip': None},
#        {'name': 'Ford Motor Co',
#         'performanceID': '0P0000029A',
#         'securityID': '0P0000029A',
#         'masterPortfolioID': None,
#         'fundID': None,
#         'ticker': None,
#         'exchange': None,
#         'exchangeCountry': None,
#         'investmentType': None,
#         'cusip': None},
#        {'name': 'Sociedad Quimica Y Minera De Chile SA',
#         'performanceID': '0P00008936',
#         'securityID': '0P00008936',
#         'masterPortfolioID': None,
#         'fundID': None,
#         'ticker': None,
#         'exchange': None,
#         'exchangeCountry': None,
#         'investmentType': None,
#         'cusip': None}],
#       'authors': [{'id': 'B4CHGNBBISETNZHVIA6UWV2SMU',
#         'rpsID': '2043',
#         'firstName': 'Seth',
#         'lastName': 'Goldstein',
#         'name': 'Seth Goldstein',
#         'freelancer': False,
#         'title': 'Strategist',
#         'byline': 'Seth Goldstein, CFA',
#         'shortBio': 'Seth Goldstein, CFA, is an equities strategist for Morningstar.',
#         'bio': [{'type': 'paragraph',
#           'text': "Seth Goldstein, CFA, is an equities strategist for Morningstar Research Services LLC, a wholly owned subsidiary of Morningstar, Inc. He covers agriculture, chemicals, and lithium companies in the basic materials sector and is also the chair of Morningstar's electric vehicle committee."},
#          {'type': 'paragraph',
#           'text': 'Prior to assuming the equity analyst role in 2017, Goldstein was an associate equity analyst covering the basic-materials sector. Before joining Morningstar, Goldstein was a senior financial analyst for Oasis Financial, a financial analyst for Berkshire Hathaway Energy, and a field operations supervisor for the U.S. Census Bureau. '},
#          {'type': 'paragraph',
#           'text': "Goldstein holds a bachelor's degree in journalism from Ohio University and a Master of Business Administration, with a concentration in finance, from the University of Iowa. He also holds the Chartered Financial Analyst® designation."}],
#         'image': {'src': 'https://s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg',
#          'srcset': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/mqw-nPbJEIwzOFiZmx_hcPpYZFo=/120x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 120w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/Z2S4uKzDUr61luwLn-Tag3yBZqk=/240x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 240w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/5fjXBmzjkGC_sf7g39eNoXQiEEc=/360x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 360w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/TvIsrTImrK8r2siTBGrN87fSy3c=/480x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 480w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/BiIPM1Xos-ZAx32MsH7eP8aLE2U=/640x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 640w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/VhMALuNmHfiNpBGTMKEu_QetapU=/720x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 720w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/JvBo9eRIfDj3qSNkhaUPHubCUjo=/960x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 960w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/7Lj8Bwru4tGwTgQxFKb_ntpVxPE=/1200x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1200w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/J5x8y1ZZ6Z6Ax38aPQlouQY_uHc=/1600x0/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1600w',
#          'variations': {'16:9': {'src': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/Cu7R97tTI1jOb8NUBN-bAvpNxJg=/2000x1125/smart/filters:no_upscale()/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg',
#            'srcset': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/2oEOmI00SYqqKKkn4iAcU2MkMfY=/120x68/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 120w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/Z_WaYwSlAWlJttW9EDZVd_nvWN4=/240x135/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 240w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/RHHCQ0h_lxms9OXXJniALhSWMCA=/360x203/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 360w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/KOZoG9iJenXpW_7yWBSG8wUuqqw=/480x270/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 480w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/vj4FBwn7luQEQniprFXvX5SYlsY=/640x360/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 640w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/TQBgDNnJ5bM43mJ1KLZi12CfMsg=/720x405/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 720w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/YaGm17gWwaOzmvtPMNvj0_YgzdQ=/960x540/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 960w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/j9bD8VS10hV9O4IUbsXj359QX8s=/1200x675/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1200w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/W8HMWrJpt8GPraqaloLqPxGTDN0=/1600x900/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1600w'},
#           '1:1': {'src': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/lgc3ot7lKgVfHaOmOsVs7aIq9ek=/2000x2000/smart/filters:no_upscale()/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg',
#            'srcset': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/LSqA1E1oFpkaZaux1qb8TERpWs8=/120x120/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 120w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/ObYT2fDeVe-cEY9s25-FZXhAvKo=/240x240/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 240w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/vcA02rGAeUIeEXyC3ij4PT5FMnM=/360x360/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 360w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/8cv5WveXzWo-42h8zPa148tsKS0=/480x480/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 480w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/xMSYqbT1M3GhABHYa_fbl_JglUA=/640x640/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 640w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/DqKyYU-rvTOYVB04DBed6dL9kbw=/720x720/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 720w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/rSuOBwyaSdOILPjNeI0waj-1y_U=/960x960/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 960w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/rb05N99AXIX_Vjsm8HPC76hQIB8=/1200x1200/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1200w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/7a53iZzYY12SNHl2C9affj8-pvU=/1600x1600/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1600w'},
#           '3:2': {'src': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/R4eal4XIEf-STPzlo5cwtBVhd3E=/2000x1333/smart/filters:no_upscale()/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg',
#            'srcset': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/TPvp3ZI22zGzeCkRPaquzOV6OQ8=/120x80/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 120w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/eDDMbJrV3WugojkpdFP4AbepBB4=/240x160/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 240w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/rreKEke91cF-CHF0aUkbtXt0shE=/360x240/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 360w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/j6SdA1yjP-lNG0EG8Co3a7Ci6_A=/480x320/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 480w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/74zmZxT3hpK5WzV4tJo0A6o7W8Y=/640x427/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 640w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/EnaitS4t6q4OvaXnkYmqHviKph0=/720x480/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 720w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/UzbP6k91ilGiGY42RiXTtuCcgB8=/960x640/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 960w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/gDrKHl49adYlcejIOrJtcdkieM8=/1200x800/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1200w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/5Gq-pxLoFHvjYNkf16JOiltKBDE=/1600x1067/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1600w'},
#           '4:3': {'src': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/xWK64FtHnSgNuiZUTlQID6nrbUg=/2000x1500/smart/filters:no_upscale()/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg',
#            'srcset': 'https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/70BXR2Bj9uFXU0tJ1QvrOeh5Phw=/120x90/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 120w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/dtKmMJhMZj7xqn-WPip0MpoJiyQ=/240x180/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 240w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/cx3OH5BBIUzYkNfqnARlOTVqMA0=/360x270/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 360w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/QGS22tXid30XYYyI4oS8UGg4vcU=/480x360/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 480w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/zH7ZD6w7zbyxWvDUZ3speN1Gyfo=/640x480/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 640w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/-2YR2XXP_9L_lIbh24TpuQzU5tU=/720x540/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 720w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/7yWdDYaOi0Qjjoe9QEwWwKNrLds=/960x720/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 960w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/MUdZyTfCIRPfC94OqexMjnU4d1k=/1200x900/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1200w, https://morningstar-morningstar-prod.web.arc-cdn.net/resizer/4ZKcdF2GwlZ7UeiLohDgoPsGqVc=/1600x1200/smart/filters:no_upscale():quality(80)/s3.amazonaws.com/arc-authors/morningstar/ca8d2ce1-cd0f-433b-a52b-d163be882398.jpg 1600w'}}},
#         'canonicalURL': '/people/seth-goldstein',
#         'active': True,
#         'books': [],
#         'podcasts': [],
#         'socials': [],
#         'disclosureStatements': None,
#         'jobTitle': 'Strategist'}],
#       'publishedDate': '2024-05-14',
#       'updatedDate': '2024-05-14',
#       'reportType': {'id': 'stock-analyst-note', 'name': 'Stock Analyst Note'},
#       'bearsSay': [],
#       'bullsSay': [],
#       'attachedNotes': [],
#       'contentElements': [{'type': 'paragraph',
#         'text': 'The US on May 13, 2024, announced a series of new tariffs on Chinese imports. These include a 100% tariff on electric vehicles and a 25% tariff on lithium-ion batteries and battery parts. There was also a 25% tariff on critical minerals, which include graphite, permanent magnets, and cobalt.'}],
#       'sections': []}],
#     'reportType': {'id': 'company-report', 'name': 'Company Report'},
#     'dataPoints': {'stockStarRating': {'field': 'stockStarRating',
#       'name': 'Morningstar Rating for Stocks',
#       'label': 'Morningstar Rating for Stocks',
#       'defaultSort': 'desc',
#       'type': 'rank',
#       'unit': 'star',
#       'defaultWidth': 112,
#       'displayWeight': 2,
#       'value': 7,
#       'properties': {'asOfDate': {'value': '2024-06-21'},
#        'date': {'value': '2024-04-25'},
#        'isQuant': {'value': False},
#        'change': {'value': 'Downgrade'},
#        'previous': {'value': 4},
#        'evaluatedPrice': {'value': 183.01000000000002}},
#       'locked': True},
#      'fairValue': {'field': 'fairValue',
#       'name': 'Fair Value',
#       'label': 'Fair Value',
#       'defaultSort': 'desc',
#       'type': 'currency',
#       'defaultWidth': 100,
#       'displayWeight': 2,
#       'value': 468,
#       'properties': {'date': {'value': '2024-04-23'},
#        'currency': {'value': 'USD'},
#        'isQuant': {'value': False},
#        'uncertainty': {'value': 'Very High', 'sortAs': 3}},
#       'locked': True},
#      'fairValueUncertainty': {'field': 'fairValueUncertainty',
#       'name': 'Fair Value Uncertainty',
#       'label': 'Fair Value Uncertainty',
#       'defaultSort': 'asc',
#       'type': 'rank',
#       'defaultWidth': 120,
#       'displayWeight': 2,
#       'value': 'Very High',
#       'sortAs': 3},
#      'economicMoat': {'field': 'economicMoat',
#       'name': 'Economic Moat',
#       'label': 'Economic Moat',
#       'defaultSort': 'desc',
#       'type': 'rank',
#       'defaultWidth': 90,
#       'displayWeight': 2,
#       'value': 'Nwhbhz',
#       'properties': {'isQuant': {'value': False},
#        'change': {'value': 'Upgrade'}},
#       'locked': True},
#      'capitalAllocationRating': {'field': 'capitalAllocationRating',
#       'name': 'Capital Allocation',
#       'label': 'Capital Allocation',
#       'defaultSort': 'desc',
#       'type': 'rank',
#       'defaultWidth': 112,
#       'displayWeight': 2,
#       'value': 'Zkrbvdmk',
#       'properties': {'date': {'value': '2024-06-21'}},
#       'locked': True}},
# ...
#         {'datetime': '2021-09-01', 'value': 3.148289},
#         {'datetime': '2021-08-02', 'value': 5.175257},
#         {'datetime': '2021-07-01', 'value': 5.48431},
#         {'datetime': '2021-06-01', 'value': 5.425791},
#         {'datetime': '2021-05-03', 'value': 6.209263},
#         {'datetime': '2021-04-01', 'value': 6.54434},
#         {'datetime': '2021-03-01', 'value': 6.283779},
#         {'datetime': '2021-02-01', 'value': 6.090298},
#         {'datetime': '2021-01-04', 'value': 6.262862},
#         {'datetime': '2020-12-01', 'value': 6.517351},
#         {'datetime': '2020-11-02', 'value': 5.065364},
#         {'datetime': '2020-10-01', 'value': 5.318293},
#         {'datetime': '2020-09-01', 'value': 3.584479},
#         {'datetime': '2020-08-03', 'value': 3.350799},
#         {'datetime': '2020-07-01', 'value': 3.350203},
#         {'datetime': '2020-06-02', 'value': 3.299533},
#         {'datetime': '2020-05-04', 'value': 3.222173},
#         {'datetime': '2020-04-01', 'value': 2.773243},
#         {'datetime': '2020-03-02', 'value': 3.57295},
#         {'datetime': '2020-02-03', 'value': 3.965975},
#         {'datetime': '2020-01-02', 'value': 4.572144},
#         {'datetime': '2019-12-02', 'value': 4.429842},
#         {'datetime': '2019-11-01', 'value': 3.998552},
#         {'datetime': '2019-10-01', 'value': 3.707183},
#         {'datetime': '2019-09-02', 'value': 3.485489},
#         {'datetime': '2019-08-01', 'value': 3.886265},
#         {'datetime': '2019-07-01', 'value': 3.931872},
#         {'datetime': '2019-06-03', 'value': 3.722897},
#         {'datetime': '2019-05-02', 'value': 4.195449},
#         {'datetime': '2019-04-01', 'value': 3.85782},
#         {'datetime': '2019-03-01', 'value': 3.998573},
#         {'datetime': '2019-02-01', 'value': 3.965943},
#         {'datetime': '2019-01-02', 'value': 3.730575},
#         {'datetime': '2018-12-03', 'value': 4.047251},
#         {'datetime': '2018-11-01', 'value': 4.125054},
#         {'datetime': '2018-10-01', 'value': 4.197574},
#         {'datetime': '2018-09-03', 'value': 4.447366},
#         {'datetime': '2018-08-01', 'value': 4.130826},
#         {'datetime': '2018-07-02', 'value': 3.939744},
#         {'datetime': '2018-06-01', 'value': 4.352827},
#         {'datetime': '2018-05-02', 'value': 4.78641},
#         {'datetime': '2018-04-03', 'value': 4.559661},
#         {'datetime': '2018-03-01', 'value': 4.483595},
#         {'datetime': '2018-02-01', 'value': 4.809484},
#         {'datetime': '2018-01-02', 'value': 4.541414},
#         {'datetime': '2017-12-01', 'value': 4.392662},
#         {'datetime': '2017-11-01', 'value': 4.664432},
#         {'datetime': '2017-10-02', 'value': 4.498404},
#         {'datetime': '2017-09-01', 'value': 4.124581},
#         {'datetime': '2017-08-01', 'value': 4.095576},
#         {'datetime': '2017-07-03', 'value': 4.307909},
#         {'datetime': '2017-06-01', 'value': 4.408624},
#         {'datetime': '2017-05-02', 'value': 4.859002},
#         {'datetime': '2017-04-03', 'value': 4.701671},
#         {'datetime': '2017-03-01', 'value': 4.670814},
#         {'datetime': '2017-02-01', 'value': 4.560335},
#         {'datetime': '2017-01-02', 'value': 4.849196},
#         {'datetime': '2016-12-01', 'value': 4.315127},
#         {'datetime': '2016-11-01', 'value': 4.433135},
#         {'datetime': '2016-10-04', 'value': 4.374834},
#         {'datetime': '2016-09-01', 'value': 4.41106},
#         {'datetime': '2016-08-01', 'value': 4.365777},
#         {'datetime': '2016-07-01', 'value': 4.416892},
#         {'datetime': '2016-06-01', 'value': 4.816947},
#         {'datetime': '2016-05-02', 'value': 5.285415},
#         {'datetime': '2016-04-01', 'value': 5.119634},
#         {'datetime': '2016-03-01', 'value': 5.139982},
#         {'datetime': '2016-02-01', 'value': 5.557677},
#         {'datetime': '2016-01-04', 'value': 6.793371},
#         {'datetime': '2015-12-01', 'value': 7.607102},
#         {'datetime': '2015-11-02', 'value': 7.626589},
#         {'datetime': '2015-10-01', 'value': 6.330974},
#         {'datetime': '2015-09-01', 'value': 6.474034},
#         {'datetime': '2015-08-03', 'value': 7.210066},
#         {'datetime': '2015-07-01', 'value': 7.87108},
#         {'datetime': '2015-06-01', 'value': 7.89066},
#         {'datetime': '2015-05-04', 'value': 8.333954},
#         {'datetime': '2015-04-01', 'value': 9.017065},
#         {'datetime': '2015-03-02', 'value': 9.109734},
#         {'datetime': '2015-02-02', 'value': 8.316023},
#         {'datetime': '2015-01-02', 'value': 7.020558},
#         {'datetime': '2014-12-01', 'value': 7.357187},
#         {'datetime': '2014-11-03', 'value': 6.751236},
#         {'datetime': '2014-10-01', 'value': 6.716399},
#         {'datetime': '2014-09-01', 'value': 6.968175},
#         {'datetime': '2014-08-01', 'value': 6.507088},
#         {'datetime': '2014-07-01', 'value': 6.928121}]}}]}},
#   'industryPeers': {'status': 200,
#    'payload': {'industry': 'Auto Manufacturers',
#     'count': 134,
#     'fields': [{'alias': 'ticker',
#       'field': 'ticker',
#       'name': 'Ticker',
#       'label': 'Ticker',
#       'attributes': {'type': 'string',
#        'defaultWidth': 90,
#        'displayWeight': 1,
#        'defaultSort': 'asc'}},
#      {'alias': 'name',
#       'field': 'name',
#       'name': 'Name',
#       'label': 'Name',
#       'attributes': {'type': 'string',
#        'defaultWidth': 280,
#        'displayWeight': 4,
#        'defaultSort': 'asc'}},
#      {'alias': 'stockStarRating',
#       'field': 'stockStarRating',
#       'name': 'Morningstar Rating for Stocks',
#       'label': 'Morningstar Rating for Stocks',
#       'attributes': {'defaultSort': 'desc',
#        'type': 'rank',
#        'unit': 'star',
#        'defaultWidth': 112,
#        'displayWeight': 2}},
#      {'alias': 'capitalAllocationRating',
#       'field': 'capitalAllocationRating',
#       'name': 'Capital Allocation',
#       'label': 'Capital Allocation',
#       'attributes': {'defaultSort': 'desc',
#        'type': 'rank',
#        'defaultWidth': 112,
#        'displayWeight': 2}},
#      {'alias': 'economicMoat',
#       'field': 'economicMoat',
#       'name': 'Economic Moat',
#       'label': 'Economic Moat',
#       'attributes': {'defaultSort': 'desc',
#        'type': 'rank',
#        'defaultWidth': 90,
#        'displayWeight': 2}},
#      {'alias': 'marketCap',
#       'field': 'marketCap',
#       'name': 'Market Cap',
#       'label': 'Market Cap',
#       'attributes': {'defaultSort': 'desc',
#        'type': 'number',
#        'unit': 'currency',
#        'magnitude': 0,
#        'defaultWidth': 80,
#        'displayWeight': 1,
#        'fractionalDigits': 0}}],
#     'results': [{'meta': {'securityID': '0P000005H4',
#        'performanceID': '0P000005H4',
#        'companyID': '0C00000CP5',
#        'universe': 'EQ',
#        'exchange': 'XNYS',
#        'ticker': 'TM'},
#       'fields': {'ticker': {'value': 'TM'},
#        'name': {'value': 'Toyota Motor Corp ADR'},
#        'stockStarRating': {'value': 7,
#         'properties': {'asOfDate': {'value': '2024-06-21'},
#          'date': {'value': '2024-05-09'},
#          'isQuant': {'value': False},
#          'change': {'value': 'Upgrade'},
#          'previous': {'value': 2},
#          'evaluatedPrice': {'value': 193.580051}},
#         'locked': True},
#        'capitalAllocationRating': {'value': 'Khwkyzx',
#         'properties': {'date': {'value': '2024-06-21'}},
#         'locked': True},
#        'economicMoat': {'value': 'Yxc',
#         'properties': {'date': {'value': '2013-01-09'},
#          'isQuant': {'value': False},
#          'change': {'value': 'Downgrade'},
#          'previous': {'value': 'Narrow', 'sortAs': 1}},
#         'locked': True},
#        'marketCap': {'value': 260473953530,
#         'properties': {'currency': {'value': 'USD'}}}}},
#      {'meta': {'securityID': '0P00016RIO',
#        'performanceID': '0P00016RIO',
#        'companyID': '0C0000AYVX',
#        'universe': 'EQ',
#        'exchange': 'XNYS',
#        'ticker': 'RACE'},
#       'fields': {'ticker': {'value': 'RACE'},
#        'name': {'value': 'Ferrari NV'},
#        'stockStarRating': {'value': 1,
#         'properties': {'asOfDate': {'value': '2024-06-21'},
#          'date': {'value': '2024-05-15'},
#          'isQuant': {'value': False},
#          'change': {'value': 'Downgrade'},
#          'previous': {'value': 2},
#          'evaluatedPrice': {'value': 414.649926}},
#         'locked': True},
#        'capitalAllocationRating': {'value': 'Bglhzyp',
#         'properties': {'date': {'value': '2024-06-21'}},
#         'locked': True},
#        'economicMoat': {'value': 'Tsfv',
#         'properties': {'isQuant': {'value': False},
#          'change': {'value': 'Upgrade'}},
#         'locked': True},
#        'marketCap': {'value': 74316650097,
#         'properties': {'currency': {'value': 'USD'}}}}},
#      {'meta': {'securityID': '0P000001MP',
#        'performanceID': '0P000001MP',
#        'companyID': '0C00000AV7',
#        'universe': 'EQ',
#        'exchange': 'PINX',
#        'ticker': 'MBGAF'},
#       'fields': {'ticker': {'value': 'MBGAF'},
#        'name': {'value': 'Mercedes-Benz Group AG'},
#        'stockStarRating': {'value': 8,
#         'properties': {'asOfDate': {'value': '2024-06-21'},
#          'date': {'value': '2024-05-22'},
#          'isQuant': {'value': False},
#          'change': {'value': 'Upgrade'},
#          'previous': {'value': 4},
#          'evaluatedPrice': {'value': 68.170044}},
#         'locked': True},
#        'capitalAllocationRating': {'value': 'Mdhlxwybv',
#         'properties': {'date': {'value': '2024-06-21'}},
#         'locked': True},
#        'economicMoat': {'value': 'Rzdljhg',
#         'properties': {'date': {'value': '2023-09-27'},
#          'isQuant': {'value': False},
#          'change': {'value': 'Upgrade'},
#          'previous': {'value': 'None', 'sortAs': 0}},
#         'locked': True},
#        'marketCap': {'value': 73968214784,
#         'properties': {'currency': {'value': 'USD'}}}}},
#      {'meta': {'securityID': '0P0000JGWS',
#        'performanceID': '0P0000JGWS',
#        'companyID': '0C000007LO',
#        'universe': 'EQ',
#        'exchange': 'XNYS',
#        'ticker': 'STLA'},
#       'fields': {'ticker': {'value': 'STLA'},
#        'name': {'value': 'Stellantis NV'},
#        'stockStarRating': {'value': 7,
#         'properties': {'asOfDate': {'value': '2024-06-21'},
#          'date': {'value': '2024-04-30'},
#          'isQuant': {'value': False},
#          'change': {'value': 'Upgrade'},
#          'previous': {'value': 4},
#          'evaluatedPrice': {'value': 20.500012}},
#         'locked': True},
#        'capitalAllocationRating': {'value': 'Mzrdydwty',
#         'properties': {'date': {'value': '2024-06-21'}},
#         'locked': True},
#        'economicMoat': {'value': 'Bhbx',
#         'properties': {'isQuant': {'value': False},
#          'change': {'value': 'Downgrade'}},
#         'locked': True},
#        'marketCap': {'value': 60173862463,
#         'properties': {'currency': {'value': 'USD'}}}}},
#      {'meta': {'securityID': '0P0000KQ4G',
#        'performanceID': '0P0000KQ4G',
#        'companyID': '0C00000ED0',
#        'universe': 'EQ',
#        'exchange': 'PINX',
#        'ticker': 'BMWYY'},
#       'fields': {'ticker': {'value': 'BMWYY'},
#        'name': {'value': 'Bayerische Motoren Werke AG ADR'},
#        'stockStarRating': {'value': 3,
#         'properties': {'asOfDate': {'value': '2024-06-21'},
#          'date': {'value': '2024-05-22'},
#          'isQuant': {'value': False},
#          'change': {'value': 'Upgrade'},
#          'previous': {'value': 4},
#          'evaluatedPrice': {'value': 31.140023}},
#         'locked': True},
#        'capitalAllocationRating': {'value': 'Dggcmmbm',
#         'properties': {'date': {'value': '2024-06-21'}},
#         'locked': True},
#        'economicMoat': {'value': 'Lfgnsk',
#         'properties': {'date': {'value': '2013-03-22'},
#          'isQuant': {'value': False},
#          'change': {'value': 'Upgrade'},
#          'previous': {'value': 'None', 'sortAs': 0}},
#         'locked': True},
#        'marketCap': {'value': 59333344752,
#         'properties': {'currency': {'value': 'USD'}}}}},
#      {'meta': {'securityID': '0P000005T6',
#        'performanceID': '0P000005T6',
#        'companyID': '0C000009K4',
#        'universe': 'EQ',
#        'exchange': 'PINX',
#        'ticker': 'VWAGY'},
#       'fields': {'ticker': {'value': 'VWAGY'},
#        'name': {'value': 'Volkswagen AG ADR'},
#        'stockStarRating': {'value': 7,
#         'properties': {'asOfDate': {'value': '2024-06-21'},
#          'date': {'value': '2022-06-13'},
#          'isQuant': {'value': False},
#          'change': {'value': 'Upgrade'},
#          'previous': {'value': 4},
#          'evaluatedPrice': {'value': 11.9899875}},
#         'locked': True},
#        'capitalAllocationRating': {'value': 'Dgtchjrg',
#         'properties': {'date': {'value': '2024-06-21'}},
#         'locked': True},
#        'economicMoat': {'value': 'Fwgm',
#         'properties': {'isQuant': {'value': False},
#          'change': {'value': 'Downgrade'}},
#         'locked': True},
#        'marketCap': {'value': 58907133797,
#         'properties': {'currency': {'value': 'USD'}}}}},
#      {'meta': {'securityID': '0P0000P7JA',
#        'performanceID': '0P0000P7JA',
#        'companyID': '0C000009K4',
#        'universe': 'EQ',
#        'exchange': 'PINX',
#        'ticker': 'VWAPY'},
#       'fields': {'ticker': {'value': 'VWAPY'},
#        'name': {'value': 'Volkswagen AG ADR'},
#        'stockStarRating': {'value': 8,
#         'properties': {'asOfDate': {'value': '2024-06-21'},
#          'date': {'value': '2021-08-19'},
#          'isQuant': {'value': False},
#          'change': {'value': 'Upgrade'},
#          'previous': {'value': 4},
#          'evaluatedPrice': {'value': 11.159999999999998}},
#         'locked': True},
#        'capitalAllocationRating': {'value': 'Ldvrklql',
#         'properties': {'date': {'value': '2024-06-21'}},
#         'locked': True},
#        'economicMoat': {'value': 'Cds',
#         'properties': {'isQuant': {'value': False},
#          'change': {'value': 'Downgrade'}},
#         'locked': True},
#        'marketCap': {'value': 58907133797,
#         'properties': {'currency': {'value': 'USD'}}}}},
#      {'meta': {'securityID': '0P0000RQZL',
#        'performanceID': '0P0000RQZL',
#        'companyID': '0C00006B5P',
#        'universe': 'EQ',
#        'exchange': 'XNYS',
#        'ticker': 'GM'},
#       'fields': {'ticker': {'value': 'GM'},
#        'name': {'value': 'General Motors Co'},
#        'stockStarRating': {'value': 9,
#         'properties': {'asOfDate': {'value': '2024-06-21'},
#          'date': {'value': '2022-04-06'},
#          'isQuant': {'value': False},
#          'change': {'value': 'Upgrade'},
#          'previous': {'value': 4},
#          'evaluatedPrice': {'value': 47.71998}},
#         'locked': True},
#        'capitalAllocationRating': {'value': 'Nljwlcf',
#         'properties': {'date': {'value': '2024-06-21'}},
#         'locked': True},
#        'economicMoat': {'value': 'Lnlrb',
#         'properties': {'isQuant': {'value': False},
#          'change': {'value': 'Downgrade'}},
#         'locked': True},
#        'marketCap': {'value': 54419642481,
#         'properties': {'currency': {'value': 'USD'}}}}},
#      {'meta': {'securityID': '0P000002PB',
#        'performanceID': '0P000002PB',
#        'companyID': '0C00000BBI',
#        'universe': 'EQ',
#        'exchange': 'XNYS',
#        'ticker': 'HMC'},
#       'fields': {'ticker': {'value': 'HMC'},
#        'name': {'value': 'Honda Motor Co Ltd ADR'},
#        'stockStarRating': {'value': 9,
#         'properties': {'asOfDate': {'value': '2024-06-21'},
#          'date': {'value': '2024-02-06'},
#          'isQuant': {'value': False},
#          'change': {'value': 'Downgrade'},
#          'previous': {'value': 4},
#          'evaluatedPrice': {'value': 31.37001}},
#         'locked': True},
#        'capitalAllocationRating': {'value': 'Zsnzrgngs',
#         'properties': {'date': {'value': '2024-06-21'}},
#         'locked': True},
#        'economicMoat': {'value': 'Rflv',
#         'properties': {'isQuant': {'value': False},
#          'change': {'value': 'Downgrade'}},
#         'locked': True},
#        'marketCap': {'value': 50358358241,
#         'properties': {'currency': {'value': 'USD'}}}}}]}}}}

# %% [markdown]
# ## API - Exchange Info

# %%
"""
website_url: https://www.morningstar.fr/fr/markets/default.aspx
api_url:  https://quotespeed.morningstar.com/service/queryPermission
=>
Comments:
=>
"""

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://quotespeed.morningstar.com/service/queryPermission'

HEADERS = {
    'accept': 'application/json, text/plain, */*',
    # 'Authorization':'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik1EY3hOemRHTnpGRFJrSTRPRGswTmtaRU1FSkdOekl5TXpORFJrUTROemd6TWtOR016bEdOdyJ9.....wJCqi9o8HUh0qUnmbAEm5OCuOqfiaiXX13fZhgiZiUVLwqMeceOfgd5ifPkB1lLSkQz9Rc_Bh5SGIK_PXlcFAzYAxHeKcFz0oGjaePIeuDQpqsZ9k-fEDlOHGTQa-uACToVIriZMP6KLewckpfYrVdqL3j6qz1p2jRNLBzd_10-A3x8KHXeMk4CgMIYPIN5Qx3s9LTXELiiOZGRe2uaOeoDBOQTwbXF1PtISV_CWG8BqvHTMzvVKQbAeLM-F_qkQRGKvifRoZshKWPtCCxhaUdRBauXak6-1ahvNdOhHHRzYht-U8BY8waTmR2gkCX29zpFlIdbG4WUMAKsUZgwT5w',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}


PAYLOAD = {
    'fields': '1,2,4,16,32,64,1024,2048,4096',
    'instid': 'EURTL',
    'sdkver': '2.62.9',
    'productType': 'sdk',
    'sessionId': '2F88466E348F15BDA66D47C6E1A6B9F0',
    '_': '1718748495056'
}

session = requests.Session()

response = session.get(URL,params=PAYLOAD, headers=HEADERS)

msg = response.json()
pd.DataFrame(msg["attachment"]["ExchangeInfo"]).transpose().reset_index().drop(columns="index")
# Out:
#     micCode delayMinute          timezone              name         shortName  \
# 0      RTSX          15     Europe/Moscow              RTSX              RTSX
# 1      XPET          -1     Europe/Moscow  Saint Petersburg  Saint Petersburg
# 2      XNGO          15        Asia/Tokyo            Nagoya            Nagoya
# 3      MISX          15     Europe/Moscow              MISX              MISX
# 4      XBOT          -1   Africa/Gaborone          Botswana          Botswana
# ..      ...         ...               ...               ...               ...
# 285    XSFA          15  America/New_York              XSFA              XSFA
# 286    XBSE          15  Europe/Bucharest         Bucharest         Bucharest
# 287    ROCO          15       Asia/Taipei            Taipei            Taipei
# 288    XZAG          15   Europe/Sarajevo            Balkan            Balkan
# 289    BCXE          15      Europe/Paris         Cboe BXTR         Cboe BXTR
#
#     gmtOffsetByMinutes estOffsetByMinutes
# 0                  180                420
# 1                  180                420
# 2                  540                780
# 3                  180                420
# 4                  120                360
# ..                 ...                ...
# 285               -240                  0
# 286                180                420
# 287                480                720
# 288                120                360
# 289                120                360
#
# [290 rows x 7 columns]

# %% [markdown]
# ## TITLE

# %%
"""
website_url: 
api_url:  
=>
Comments:
=>
"""
import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://www.us-api.morningstar.com/sal/sal-service/stock/realTime/v3/0P000000GY/data'

HEADERS = {
    'Accept':'*/*',
    'Accept-Encoding':'gzip, deflate, br, zstd',
    'Accept-Language':'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'Authorization':'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik1EY3hOemRHTnpGRFJrSTRPRGswTmtaRU1FSkdOekl5TXpORFJrUTROemd6TWtOR016bEdOdyJ9.....YxeJmJZGcN7JwxUu2ITcYRIco98nimJm-Do60JKI5VeP5-VCVTV3ch7gUemnxpztgw9z7ATPXEpiZGpEt5ppNsjdVzT9MDVTcHRbeW74VljLiQ_UgzDplyb1LKdlPWLeIKB8wywLHErhuzdT6klj1OEQ5DpwzbFtIs9Wte1pw8qBw4U3YStS1dFjqmyyIiT7N_sQ6yxqfrkNKZ58f-4EQWVisAl_89dj2AHxZCpb99vFVbyjm85HbOxLaycP_QSjr1RzbRCBmUL8TU4vmSTRREgXOlrM2p8meERxv5pRk8ZnFNgBoy3N_xpRtdfLvuJLlqtnd0k-BD6KRMj6qVOirw',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
    'Cache-Control':    'no-cache, no-store, must-revalidate',
    'Credentials':    'omit',
    'Origin':    'https://www.morningstar.ca',
    'Priority':    'u=1, i',
    'Referer':    'https://www.morningstar.ca/ca/report/stocks/quote.aspx?t=0P000000GY&lang=en-CA'
}

PAYLOAD = {
    'languageId': 'en',
    # 'random': '0.04056044847466067',
    'locale': 'en',
    'clientId': 'MDC_intl',
    'component': 'sal-components-quote',
    'version': '3.60.0'
}

session = requests.Session()

response = session.get(URL,params=PAYLOAD, headers=HEADERS)

response
# Out:
# <Response [401]>

# %% [markdown]
# ## TITLE

# %%
"""
website_url: 
api_url:  
=>
Comments:
=>
"""

import requests

# Define the request URL
url = "https://api-global.morningstar.com/sal-service/v1/stock/header/v2/data/0P000000B7/securityInfo"
       

# Define the headers
headers = {
    'Accept': '*/*',
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Accept-Language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'Origin': 'https://www.morningstar.com.au',
    'Referer': 'https://www.morningstar.com.au/',
    'Sec-Ch-Ua': '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
    'Sec-Ch-Ua-Mobile': '?0',
    'Sec-Ch-Ua-Platform': '"Windows"',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'cross-site',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
    'X-Api-Realtime-E': 'eyJlbmMiOiJBMTI4R0NNIiwiYWxnIjoiUlNBLU9BRVAifQ.1E4oJB3HCtJ2PdjKIIZICy5ezgGD2CykvEXGcogbPOlg_A41fdjqwbj9a8wSutGt14Cyvts7e5n9MgtHb4KFQ7D6ou1jJu7O12M-O35vJSHWJqW4Co7pPqIf6U7-V3_hMcuu1RNRwrtFL9ic47obcJcZdVWx1TxrQjl0ouYnAIc.Hl4r5ODE4AWxcugW.-st5MrpSB660aH9VrqiGow1UHcGGfGMOFRHbMCU3mw1VGwox5JZQkI-_-Bv-8wxrxLxJbRt8QUjI1TcHD-pfAQ7XKlRjh8Q1WxM9PRMEU7mSQ4x5R8LShijyErCFTIUMMGSuz8caAk18JowkpGOcBaSCvqEO8ZlzJs1qjmH9VtrRiFiQItaQvzdSUcEYFYiEEIEMn4Ay9d9Fz69zKqwVZqUqyQWZBBVDM2MOzZI.v3Du6IgztOU7b3FlWHdpyA',
    'X-Api-Requestid': '02be7774-e78a-85ef-5cd5-0e2936745777',
    'X-Sal-Contenttype': 'e7FDDltrTy+tA2HnLovvGL0LFMwT+KkEptGju5wXVTU='
}

# Make the GET request

response = session.get(URL,params=PAYLOAD, headers=HEADERS)

# Check if the request was successful
if response.status_code == 200:
    # Print the response content
    print(response.json())
else:
    print(f"Request failed with status code {response.status_code}")
# Out:
# Request failed with status code 404

# %% [markdown]
# ## TITLE

# %%
"""
website_url: 
api_url:  
=>
Comments:
=>
"""
import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://www.morningstar.com/api/v2/stocks/details/LU0011963245USD'

HEADERS = {
    'Accept':'*/*',
    "Content-Type": "application/json",
    'Accept-Encoding':'gzip, deflate, br, zstd',
    'Accept-Language':'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'Authorization':'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik1EY3hOemRHTnpGRFJrSTRPRGswTmtaRU1FSkdOekl5TXpORFJrUTROemd6TWtOR016bEdOdyJ9.....Hj229brtbPTMR2t2lwicBLuzd2FUN2BqxoZPHUrf_AMmnRf1ejnm-6ha86ShulBlkUxdLRliDj7jg_Ax5sHWDD7zj7jNvjqaur2wICuzKXrjZO5iCrJzkr247VKmJxkfyTsW6ZUnjf1X83le6FEJ0iUcRdY_mVzCTowg-OBDkTFte2RHNcRMFX1824MGTEgN9cqGkA9NEEdJtvlmNR02WPnuroiom9HPnQf427CWwrmpdd1h0VwxIzQDteXiLXGchIxUZ3FgmbJZDUCQn02jhG0el83IjEiZIhN6yQuzc_lzGfmkD0-Yvfl8Dfy3qLCpQnaEtLX0gjeFjb1N8i3S9A',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
    'Cache-Control':    'no-cache, no-store, must-revalidate',
}

PAYLOAD = {
    'id': 'LU0011963245USD',
}

# Make the GET request
session = requests.Session()
# response = requests.get(URL, headers=HEADERS, params=PAYLOAD)
response = requests.get(URL, headers=HEADERS)

response
# Out:
# <Response [404]>

# %% [markdown]
# ## TITLE

# %%
"""
website_url: https://www.morningstar.com/stocks/xnas/nvda/quote
api_url:  https://www.morningstar.com/api/v2/stores/realtime/quotes
=>
Comments:
=> The url can be used to get company information
"""

import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://www.morningstar.com/api/v2/stores/realtime/quotes'

HEADERS = {
    'Accept':'*/*',
    "Content-Type": "application/json",
    'Accept-Encoding':'gzip, deflate, br, zstd',
    'Accept-Language':'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'Cookie':'_cb=CHQE1OH0npskmPmL; mid=7136847794596326555; msession=29fc031e-3dc2-45fa-92d6-c062d4a90e47.88eae3068a44b61d77de9d7cde0af5c88f95a48da7d5e117c29d68a0ec966271; ELOQUA=GUID=7E6FFEC9AE384AF6B953EFE8F77580F4; _ga_ZHP6HH58B1=GS1.1.1708771783.1.0.1708771785.58.0.0; _gcl_au=1.1.848195055.1718742360; _gd_svisitor=355a16020d310000a0b1526347010000f06d0a00; _an_uid=9128226608692305453; _gd_visitor=c2265828-5d85-47b6-8f3c-465cd2c35358; ELQCOUNTRY=FR; _uetvid=97394690a6dc11ed88aad9eefd0db656; optimizelyEndUserId=oeu1718750700294r0.6385944550700966; OptanonConsent=isGpcEnabled=0&datestamp=Sat+Jun+22+2024+15%3A25%3A19+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202306.1.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=4abfe687-a1f5-439c-99ce-cb83973277f0&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0003%3A0%2CC0002%3A0%2CC0004%3A0&AwaitingReconsent=false; _ga_LMTVSGTMT2=GS1.1.1719062675.1.1.1719063653.0.0.0; _ga_SW6G2BFREG=GS1.1.1719062675.1.1.1719063653.0.0.0; _ga_DLZP83KFTR=GS1.1.1719062675.1.1.1719063653.0.0.0; mbuddy=eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXSyIsImtpZCI6IjE2NjYwMjExMjkifQ.eyJzZXNzaW9uIjoiMjlmYzAzMWUtM2RjMi00NWZhLTkyZDYtYzA2MmQ0YTkwZTQ3Ljg4ZWFlMzA2OGE0NGI2MWQ3N2RlOWQ3Y2RlMGFmNWM4OGY5NWE0OGRhN2Q1ZTExN2MyOWQ2OGEwZWM5NjYyNzEiLCJpYXQiOjE3MTkxNTc5NjMsImlzcyI6Imh0dHBzOi8vaW52ZXN0b3IubW9ybmluZ3N0YXIuY29tIiwiZXhwIjoxNzE5MTU4MjYzfQ.ZQBWGVMFGECwK81TFm6CUSHl-g_4EsR-la015Svg_HS6bIY0Qhyv8VDSD_wTYk28nHeT7GDPRcs-KiNvVSF8iGpJZ10641xh8nlQ3s2M8pJ2pJRtnVsQ-eY-01grjADu-1HeShuWmk2Z1MzLc13LO4fyymPivCPRcMvZiFVVBhaX2WCCYDC_PEZg8kxP0y3leRhzvwBwa8GbsAlhBRVRzXbl2wJy9RRlLA3zoQ1jnMWqvXkJpD_TgloY-IjLr4uvNr6l3KS6yFZY1Dn_hVZXEhjKIDPsqIR2L21p4ZJ7V9RU4gvDo_msbujVtXLk0onn-hn-wQ2GIZxIEjyCYHlWcA; _t_tests=eyI2VDFVQmg4VHhFS29YIjp7ImNob3NlblZhcmlhbnQiOiJCIiwic3BlY2lmaWNMb2NhdGlvbiI6WyJ1TXViSyJdfSwiVk5zVlpzN2wyR0l5MCI6eyJjaG9zZW5WYXJpYW50IjoiQiIsInNwZWNpZmljTG9jYXRpb24iOlsibGt5VUciXX0sImxpZnRfZXhwIjoibSJ9; _gid=GA1.2.883470884.1719157982; _dc_gtm_UA-141496933-1=1; _cb_svref=external; _gd_session=7dcd88d1-a176-48e8-8e90-3b1331c3d8c1; _ga=GA1.2.1026723484.1708771784; _chartbeat2=.1675770197818.1719157984937.0000000000110011.DsbmO5BjVt1pC25CwzCgdVW9DpE2kF.2; _chartbeat5=; _chartbeat4=t=BhInNoDgj3RCBIdR1mB2vkZdXby5S&E=3&x=500&c=0.14&y=6433&w=911; _ga_G8C0R44VCK=GS1.1.1719157982.4.1.1719157993.0.0.0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
}

PAYLOAD = {
    'securities': 'xnas:nvda',
}

# Make the GET request
session = requests.Session()
response = requests.get(URL, headers=HEADERS, params=PAYLOAD)


pd.DataFrame(response.json())
# Out:
#                                                              xnas:nvda  \
# postMarketNetChange  {'value': 0.42, 'properties': {'currency': {'v...
# preMarketNetChange   {'value': -3.67, 'properties': {'currency': {'...
# openPrice            {'value': 127.12, 'properties': {'currency': {...
# tradingStatus        {'value': 'Closed', 'properties': {'exchange':...
# lowPrice             {'value': 124.3, 'properties': {'currency': {'...
# highPrice            {'value': 130.63, 'properties': {'currency': {...
# percentNetChange     {'value': -3.2191, 'properties': {'date': {'va...
# preMarketPrice       {'value': 127.11, 'properties': {'currency': {...
# netChange            {'value': -4.21, 'properties': {'date': {'valu...
# askPrice             {'value': 127, 'properties': {'date': {'value'...
# marketCap            {'value': 3113412143142.9, 'properties': {'cur...
# ticker                             {'value': 'NVDA', 'properties': {}}
# adjustedClosePrice   {'value': 130.78, 'properties': {'currency': {...
# yearLowPrice         {'value': 39.23001, 'properties': {'date': {'v...
# bidPrice             {'value': 126.98, 'properties': {'date': {'val...
# previousClosePrice   {'value': 130.78, 'properties': {'date': {'val...
# volume               {'value': 655484664, 'properties': {'date': {'...
# postMarketPrice      {'value': 126.99, 'properties': {'currency': {...
# performanceID                {'value': '0P000003RE', 'properties': {}}
# averageVolume        {'value': 445092664.828125, 'properties': {'ex...
# listedCurrency                      {'value': 'USD', 'properties': {}}
# name                        {'value': 'NVIDIA Corp', 'properties': {}}
# exchange                           {'value': 'XNAS', 'properties': {}}
# yearHighPrice        {'value': 195.95, 'properties': {'date': {'val...
# lastPrice            {'value': 126.57, 'properties': {'date': {'val...
#
#                                                              undefined
# postMarketNetChange  {'value': 0.42, 'properties': {'currency': {'v...
# preMarketNetChange   {'value': -3.67, 'properties': {'currency': {'...
# openPrice            {'value': 127.12, 'properties': {'currency': {...
# tradingStatus        {'value': 'Closed', 'properties': {'exchange':...
# lowPrice             {'value': 124.3, 'properties': {'currency': {'...
# highPrice            {'value': 130.63, 'properties': {'currency': {...
# percentNetChange     {'value': -3.2191, 'properties': {'date': {'va...
# preMarketPrice       {'value': 127.11, 'properties': {'currency': {...
# netChange            {'value': -4.21, 'properties': {'date': {'valu...
# askPrice             {'value': 127, 'properties': {'date': {'value'...
# marketCap            {'value': 3113412143142.9, 'properties': {'cur...
# ticker                             {'value': 'NVDA', 'properties': {}}
# adjustedClosePrice   {'value': 130.78, 'properties': {'currency': {...
# yearLowPrice         {'value': 39.23001, 'properties': {'date': {'v...
# bidPrice             {'value': 126.98, 'properties': {'date': {'val...
# previousClosePrice   {'value': 130.78, 'properties': {'date': {'val...
# volume               {'value': 655484664, 'properties': {'date': {'...
# postMarketPrice      {'value': 126.99, 'properties': {'currency': {...
# performanceID                {'value': '0P000003RE', 'properties': {}}
# averageVolume        {'value': 445092664.828125, 'properties': {'ex...
# listedCurrency                      {'value': 'USD', 'properties': {}}
# name                        {'value': 'NVIDIA Corp', 'properties': {}}
# exchange                           {'value': 'XNAS', 'properties': {}}
# yearHighPrice        {'value': 195.95, 'properties': {'date': {'val...
# lastPrice            {'value': 126.57, 'properties': {'date': {'val...

# %% [markdown]
# ## TITLE

# %%
"""
website_url: https://www.morningstar.com/stocks/xnas/nvda/quote
api_url:  https://www.morningstar.com/api/v2/stores/realtime/quotes
=>
Comments:
=> The url can be used to get timeseries with approximatly 5min intervals. 
"""

import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://www.morningstar.com/api/v2/stores/realtime/timeseries'

HEADERS = {
    'Accept':'*/*',
    "Content-Type": "application/json",
    'Accept-Encoding':'gzip, deflate, br, zstd',
    'Accept-Language':'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'Cookie':'_cb=CHQE1OH0npskmPmL; mid=7136847794596326555; msession=29fc031e-3dc2-45fa-92d6-c062d4a90e47.88eae3068a44b61d77de9d7cde0af5c88f95a48da7d5e117c29d68a0ec966271; ELOQUA=GUID=7E6FFEC9AE384AF6B953EFE8F77580F4; _ga_ZHP6HH58B1=GS1.1.1708771783.1.0.1708771785.58.0.0; _gcl_au=1.1.848195055.1718742360; _gd_svisitor=355a16020d310000a0b1526347010000f06d0a00; _an_uid=9128226608692305453; _gd_visitor=c2265828-5d85-47b6-8f3c-465cd2c35358; ELQCOUNTRY=FR; _uetvid=97394690a6dc11ed88aad9eefd0db656; optimizelyEndUserId=oeu1718750700294r0.6385944550700966; OptanonConsent=isGpcEnabled=0&datestamp=Sat+Jun+22+2024+15%3A25%3A19+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202306.1.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=4abfe687-a1f5-439c-99ce-cb83973277f0&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0003%3A0%2CC0002%3A0%2CC0004%3A0&AwaitingReconsent=false; _ga_LMTVSGTMT2=GS1.1.1719062675.1.1.1719063653.0.0.0; _ga_SW6G2BFREG=GS1.1.1719062675.1.1.1719063653.0.0.0; _ga_DLZP83KFTR=GS1.1.1719062675.1.1.1719063653.0.0.0; mbuddy=eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXSyIsImtpZCI6IjE2NjYwMjExMjkifQ.eyJzZXNzaW9uIjoiMjlmYzAzMWUtM2RjMi00NWZhLTkyZDYtYzA2MmQ0YTkwZTQ3Ljg4ZWFlMzA2OGE0NGI2MWQ3N2RlOWQ3Y2RlMGFmNWM4OGY5NWE0OGRhN2Q1ZTExN2MyOWQ2OGEwZWM5NjYyNzEiLCJpYXQiOjE3MTkxNTc5NjMsImlzcyI6Imh0dHBzOi8vaW52ZXN0b3IubW9ybmluZ3N0YXIuY29tIiwiZXhwIjoxNzE5MTU4MjYzfQ.ZQBWGVMFGECwK81TFm6CUSHl-g_4EsR-la015Svg_HS6bIY0Qhyv8VDSD_wTYk28nHeT7GDPRcs-KiNvVSF8iGpJZ10641xh8nlQ3s2M8pJ2pJRtnVsQ-eY-01grjADu-1HeShuWmk2Z1MzLc13LO4fyymPivCPRcMvZiFVVBhaX2WCCYDC_PEZg8kxP0y3leRhzvwBwa8GbsAlhBRVRzXbl2wJy9RRlLA3zoQ1jnMWqvXkJpD_TgloY-IjLr4uvNr6l3KS6yFZY1Dn_hVZXEhjKIDPsqIR2L21p4ZJ7V9RU4gvDo_msbujVtXLk0onn-hn-wQ2GIZxIEjyCYHlWcA; _t_tests=eyI2VDFVQmg4VHhFS29YIjp7ImNob3NlblZhcmlhbnQiOiJCIiwic3BlY2lmaWNMb2NhdGlvbiI6WyJ1TXViSyJdfSwiVk5zVlpzN2wyR0l5MCI6eyJjaG9zZW5WYXJpYW50IjoiQiIsInNwZWNpZmljTG9jYXRpb24iOlsibGt5VUciXX0sImxpZnRfZXhwIjoibSJ9; _gid=GA1.2.883470884.1719157982; _dc_gtm_UA-141496933-1=1; _cb_svref=external; _gd_session=7dcd88d1-a176-48e8-8e90-3b1331c3d8c1; _ga=GA1.2.1026723484.1708771784; _chartbeat2=.1675770197818.1719157984937.0000000000110011.DsbmO5BjVt1pC25CwzCgdVW9DpE2kF.2; _chartbeat5=; _chartbeat4=t=BhInNoDgj3RCBIdR1mB2vkZdXby5S&E=3&x=500&c=0.14&y=6433&w=911; _ga_G8C0R44VCK=GS1.1.1719157982.4.1.1719157993.0.0.0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
}

PAYLOAD = {
    'securities': 'xmun:HH20',
}

# Make the GET request
session = requests.Session()
response = requests.get(URL, headers=HEADERS, params=PAYLOAD)
msg = response.json()
# pd.DataFrame(msg['xnas:nvda']['intervals'])
msg
# Out:
# {'xmun:HH20': None}

# %% [markdown]
# ## TITLE

# %%
"""
website_url: 
api_url:  
=>
Comments:
=>
"""

#Code
