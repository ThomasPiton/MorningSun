# %% [markdown]
# # List WEBSITE_NAME Endpoints:

# %%
[
    # 
    "https://www.us-api.morningstar.com/QS-markets/chartservice/v2/timeseries",
    # 
    "https://www.morningstar.com/api/v2/stores/realtime/quotes",
    # 
    "https://www.morningstar.com/api/v2/investing-definitions/by-fields",
    # 
    "https://www.morningstar.com/api/v2/stocks/xnas/tsla/quote",
    # 
    "https://api-global.morningstar.com/sal-service/v1/stock/esgRisk/sustainability",
    # 
    "https://api-global.morningstar.com/sal-service/v1/stock/keyratios/0P0000OQN8/data"
    # 
    "https://api-global.morningstar.com/sal-service/v1/stock/operatingPerformance/v2/0P0000OQN8",
    # 
    "https://api-global.morningstar.com/sal-service/v1/stock/insiders/boardOfDirectors/0P0000OQN8/data",
    # 
    "https://api-global.morningstar.com/sal-service/v1/stock/insiders/transactionHistory/0P0000OQN8/data",
    # 
    "https://api-global.morningstar.com/sal-service/v1/stock/insiders/transactionChart/0P0000OQN8/data",
    # 
    "https://api-global.morningstar.com/sal-service/v1/stock/ownership/v1/0P0000OQN8/OwnershipData/mutualfund/20/data",
    #
    "https://api-global.morningstar.com/sal-service/v1/stock/header/v2/data/0P000000B7/securityInfo"
    # 
    "https://www.us-api.morningstar.com/sal/sal-service/stock/realTime/v3/0P000000GY/data"
    # Official endpoint from https://developer.morningstar.com/direct-web-services/documentation/api-reference/time-series/price
    "https://www.us-api.morningstar.com/ecint/v1/timeseries/price"
]
# Out:
# ['https://www.us-api.morningstar.com/QS-markets/chartservice/v2/timeseries',
#  'https://www.morningstar.com/api/v2/stores/realtime/quotes',
#  'https://www.morningstar.com/api/v2/investing-definitions/by-fields',
#  'https://www.morningstar.com/api/v2/stocks/xnas/tsla/quote',
#  'https://api-global.morningstar.com/sal-service/v1/stock/esgRisk/sustainability',
#  'https://api-global.morningstar.com/sal-service/v1/stock/keyratios/0P0000OQN8/datahttps://api-global.morningstar.com/sal-service/v1/stock/operatingPerformance/v2/0P0000OQN8',
#  'https://api-global.morningstar.com/sal-service/v1/stock/insiders/boardOfDirectors/0P0000OQN8/data',
#  'https://api-global.morningstar.com/sal-service/v1/stock/insiders/transactionHistory/0P0000OQN8/data',
#  'https://api-global.morningstar.com/sal-service/v1/stock/insiders/transactionChart/0P0000OQN8/data',
#  'https://api-global.morningstar.com/sal-service/v1/stock/ownership/v1/0P0000OQN8/OwnershipData/mutualfund/20/data',
# ...

# %% [markdown]
# ## MAPPING

# %%
MAPPING_ = []

# %% [markdown]
# ## DOCUMENTS

# %%
https://developer.morningstar.com/direct-web-services/documentation/api-reference/screener/esg-screener
# Out:
#   Cell In[3], line 1
#     https://developer.morningstar.com/direct-web-services/documentation/api-reference/screener/esg-screener
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## API - Timeseries

# %%
"""
website_url: https://www.morningstar.com/stocks/xnas/tsla/chart
api_url: https://www.us-api.morningstar.com/QS-markets/chartservice/v2/timeseries
=>
Comments: to get timeseries data
=>
"""

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://www.us-api.morningstar.com/QS-markets/chartservice/v2/timeseries'

HEADERS = {
    'accept': 'application/json, text/plain, */*',
    'Authorization':'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik1EY3hOemRHTnpGRFJrSTRPRGswTmtaRU1FSkdOekl5TXpORFJrUTROemd6TWtOR016bEdOdyJ9.....wJCqi9o8HUh0qUnmbAEm5OCuOqfiaiXX13fZhgiZiUVLwqMeceOfgd5ifPkB1lLSkQz9Rc_Bh5SGIK_PXlcFAzYAxHeKcFz0oGjaePIeuDQpqsZ9k-fEDlOHGTQa-uACToVIriZMP6KLewckpfYrVdqL3j6qz1p2jRNLBzd_10-A3x8KHXeMk4CgMIYPIN5Qx3s9LTXELiiOZGRe2uaOeoDBOQTwbXF1PtISV_CWG8BqvHTMzvVKQbAeLM-F_qkQRGKvifRoZshKWPtCCxhaUdRBauXak6-1ahvNdOhHHRzYht-U8BY8waTmR2gkCX29zpFlIdbG4WUMAKsUZgwT5w',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}

PAYLOAD = {
    'query': '0P0000OQN8:open,high,low,close,volume,previousClose',
    'frequency': 1,
    'preAfter': False,
    'tradingDays': 1,
    'trackMarketData': '3.6.3',
    'instid': 'DOTCOM'
}

session = requests.Session()

response = session.get(URL,params=PAYLOAD, headers=HEADERS)

msg = response.json()

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Proceed Data

data = msg[0]["series"][0]["children"]

df = pd.DataFrame(data)

df["date"] = pd.to_datetime(df['date']).dt.strftime('%Y-%m-%d %H:%M:%S')

df = df[["date","open","high","low","close","volume"]]

df
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\Thomas\VS\MorningSun\env\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %% [markdown]
# ## API - Last News

# %%
"""
website_url: https://www.morningstar.com/stocks/xnas/tsla/news
api_url:  https://www.morningstar.com/api/v2/{stocks}/{xnas}/{tsla}/news
=>
Comments: to extract last news
=>
"""

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://www.morningstar.com/api/v2/stocks/xnas/tsla/news'

HEADERS = {
    'accept': 'application/json, text/plain, */*',
    # 'Authorization':'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik1EY3hOemRHTnpGRFJrSTRPRGswTmtaRU1FSkdOekl5TXpORFJrUTROemd6TWtOR016bEdOdyJ9.....wJCqi9o8HUh0qUnmbAEm5OCuOqfiaiXX13fZhgiZiUVLwqMeceOfgd5ifPkB1lLSkQz9Rc_Bh5SGIK_PXlcFAzYAxHeKcFz0oGjaePIeuDQpqsZ9k-fEDlOHGTQa-uACToVIriZMP6KLewckpfYrVdqL3j6qz1p2jRNLBzd_10-A3x8KHXeMk4CgMIYPIN5Qx3s9LTXELiiOZGRe2uaOeoDBOQTwbXF1PtISV_CWG8BqvHTMzvVKQbAeLM-F_qkQRGKvifRoZshKWPtCCxhaUdRBauXak6-1ahvNdOhHHRzYht-U8BY8waTmR2gkCX29zpFlIdbG4WUMAKsUZgwT5w',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}



session = requests.Session()

response = session.get(URL, headers=HEADERS)

msg = response.json()
df = pd.DataFrame(msg["components"]["news"]["payload"])
df
# Out:
#                  id       sourceId          sourceName   providerName  \
# 0   20251003dc87706    pr-newswire         PR Newswire    PR Newswire
# 1       20251002422    marketwatch         MarketWatch      Dow Jones
# 2       20251002209    marketwatch         MarketWatch      Dow Jones
# 3      202510023867      dow-jones  Global News Select      Dow Jones
# 4    20251002153810  business-wire       Business Wire  Business Wire
# 5   20251001ny86027    pr-newswire         PR Newswire    PR Newswire
# 6       20250930367    marketwatch         MarketWatch      Dow Jones
# 7     2025092910982      dow-jones  Global News Select      Dow Jones
# 8   20250929ny84588    pr-newswire         PR Newswire    PR Newswire
# 9       20250928146    marketwatch         MarketWatch      Dow Jones
# 10  20250928dc83418    pr-newswire         PR Newswire    PR Newswire
# 11  20250926ny83855    pr-newswire         PR Newswire    PR Newswire
# ...

# %% [markdown]
# ## API - Sustainability

# %%
"""
website_url: https://www.morningstar.com/stocks/xnas/tsla/sustainability
api_url: https://api-global.morningstar.com/sal-service/v1/{stock}/esgRisk/sustainability/{0P0000OQN8}/data 
=>
Comments: ATTENTION NEED TO FIND A METHOD TO GET THE APIKEY !!
=>
"""
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://api-global.morningstar.com/sal-service/v1/stock/esgRisk/sustainability/0P0000OQN8/data'

HEADERS = {
    'Accept':'*/*',
    'Accept-Encoding':    'gzip, deflate, br, zstd',
    'Accept-Language':    'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'Apikey':    'lstzFDEOhfFNMLikKa0am9mgEKLBl49T',
    'Origin':    'https://www.morningstar.com',
    'Priority':    'u=1, i',
    'Referer':    'https://www.morningstar.com/stocks/xnas/tsla/sustainability',
    'Sec-Ch-Ua':    '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
    'Sec-Ch-Ua-Mobile':    '?0',
    'Sec-Ch-Ua-Platform':    "Windows",
    'Sec-Fetch-Dest':    'empty',
    'Sec-Fetch-Mode':    'cors',
    'Sec-Fetch-Site':    'same-site',
    'User-Agent':    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}

PAYLOAD = {
    'languageId': 'en',
    'locale': 'en',
    'clientId': 'MDC',
    'component': 'sal-eqsv-risk-rating-breakdown',
    'version': '4.30.0'
}

session = requests.Session()

response = session.get(URL,params=PAYLOAD, headers=HEADERS)

msg = response.json()

df = pd.DataFrame(msg).iloc[0:1].transpose().reset_index().rename(columns={"index":"variable",0:"value"})

df
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\Thomas\VS\MorningSun\env\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %% [markdown]
# ## API - Token

# %%
"""
website_url: 
api_url:  
=>
Comments:
=>
"""

import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://www.morningstar.com/api/v2/stores/maas/token'

HEADERS = {
    'accept': 'application/json, text/plain, */*',
    # 'Authorization':'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik1EY3hOemRHTnpGRFJrSTRPRGswTmtaRU1FSkdOekl5TXpORFJrUTROemd6TWtOR016bEdOdyJ9.....wJCqi9o8HUh0qUnmbAEm5OCuOqfiaiXX13fZhgiZiUVLwqMeceOfgd5ifPkB1lLSkQz9Rc_Bh5SGIK_PXlcFAzYAxHeKcFz0oGjaePIeuDQpqsZ9k-fEDlOHGTQa-uACToVIriZMP6KLewckpfYrVdqL3j6qz1p2jRNLBzd_10-A3x8KHXeMk4CgMIYPIN5Qx3s9LTXELiiOZGRe2uaOeoDBOQTwbXF1PtISV_CWG8BqvHTMzvVKQbAeLM-F_qkQRGKvifRoZshKWPtCCxhaUdRBauXak6-1ahvNdOhHHRzYht-U8BY8waTmR2gkCX29zpFlIdbG4WUMAKsUZgwT5w',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}

session = requests.Session()

response = session.get(URL, headers=HEADERS)

response.text
# Out:
# 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik1EY3hOemRHTnpGRFJrSTRPRGswTmtaRU1FSkdOekl5TXpORFJrUTROemd6TWtOR016bEdOdyJ9.....e-UOrvsAyc86OEP3Pwwz8c2ncwQX2oBiTq30301qFvT7UnKIYBq0JKNuMEzOORtRdeoLcT4Qn1iNIMsQHr6hRJRXUlE9aUfep9JOSLFo6J3ivrWNo8EeAYyeXCJAIldWDImlb5j-Ue1SXAMt1LzQuC3LmgL3ONHglxruydKnNx3X5pTVaQxnVFwd5Ob3ay8gaztJc04k25gwoFKziG-3SgEZ8DEHbCWAXJXLN7iQRz3ed1qhlnyl6hHisXpIbrziIAWUSAt7GT72nN6ihPKpzqoUGu4cT0fq4Nhpc1iOL73jHHNWQMWVA1pq3lNsG4cp_m5EeJXh0sq46sKjzLowbg'

# %% [markdown]
# ## API - VALUATION

# %%
"""
website_url:  https://www.morningstar.com/stocks/xnas/tsla/valuation
api_url:  https://api-global.morningstar.com/sal-service/v1/stock/keyratios/0P0000OQN8/data
=>
Comments:
=>
"""

#Code
import requests
import pandas as pd

# Set the URL you want to scrape from
URL = 'https://api-global.morningstar.com/sal-service/v1/stock/keyratios/0P0000OQN8/data'

HEADERS = {
    'Accept':'*/*',
    'Accept-Encoding':    'gzip, deflate, br, zstd',
    'Accept-Language':    'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'Apikey':    'lstzFDEOhfFNMLikKa0am9mgEKLBl49T',
    'Origin':    'https://www.morningstar.com',
    'Priority':    'u=1, i',
    'Referer':    'https://www.morningstar.com/stocks/xnas/tsla/sustainability',
    'Sec-Ch-Ua':    '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
    'Sec-Ch-Ua-Mobile':    '?0',
    'Sec-Ch-Ua-Platform':    "Windows",
    'Sec-Fetch-Dest':    'empty',
    'Sec-Fetch-Mode':    'cors',
    'Sec-Fetch-Site':    'same-site',
    'User-Agent':    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}

PAYLOAD = {
    'languageId': 'en',
    'locale': 'en',
    'clientId': 'MDC',
    'component': 'sal-key-stats-overview',
    'version': '4.30.0'
}

session = requests.Session()

response = session.get(URL,params=PAYLOAD, headers=HEADERS)
msg = response.json()
pd.DataFrame(msg)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\Thomas\VS\MorningSun\env\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %% [markdown]
# ## API - VALUATION

# %%
"""
website_url: https://www.morningstar.com/stocks/xnas/tsla/performance
api_url:  https://api-global.morningstar.com/sal-service/v1/stock/operatingPerformance/v2/0P0000OQN8
=>
Comments:
=>
"""

import requests

# Set the URL you want to scrape from
URL = 'https://api-global.morningstar.com/sal-service/v1/stock/operatingPerformance/v2/0P0000OQN8'

HEADERS = {
    'Accept':'*/*',
    'Accept-Encoding':    'gzip, deflate, br, zstd',
    'Accept-Language':    'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'Apikey':    'lstzFDEOhfFNMLikKa0am9mgEKLBl49T',
    'Origin':    'https://www.morningstar.com',
    'Priority':    'u=1, i',
    'Referer':    'https://www.morningstar.com/stocks/xnas/tsla/sustainability',
    'Sec-Ch-Ua':    '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
    'Sec-Ch-Ua-Mobile':    '?0',
    'Sec-Ch-Ua-Platform':    "Windows",
    'Sec-Fetch-Dest':    'empty',
    'Sec-Fetch-Mode':    'cors',
    'Sec-Fetch-Site':    'same-site',
    'User-Agent':    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}

PAYLOAD = {
    'languageId': 'en',
    'locale': 'en',
    'clientId': 'MDC',
    'component': 'sal-oper-perf',
    'version': '4.30.0'
}

session = requests.Session()

response = session.get(URL,params=PAYLOAD, headers=HEADERS)
msg = response.json()
pd.DataFrame(msg)
# Out:
#                                               _meta  \
# responseStatus                               200700
# hint               Securities successfully returned
# performanceId                            0P0000OQN8
# reportType                                      NaN
# reportType_label                                NaN
# columnDefs                                      NaN
# columnDefs_labels                               NaN
# Collapsed                                       NaN
# Expanded                                        NaN
# indexLabel                                      NaN
# indexName                                       NaN
# asOfDate                                        NaN
# fiscalYearEndDate                               NaN
# ebitdaCurrency                                  NaN
#
#                                                             reported  \
# responseStatus                                                   NaN
# ...

# %% [markdown]
# ## API - Ownership

# %%
"""
website_url: https://www.morningstar.com/stocks/xnas/tsla/ownership
api_url:  https://api-global.morningstar.com/sal-service/v1/stock/ownership/v1/0P0000OQN8/OwnershipData/mutualfund/20/data
=>
Comments:
=>
"""

import requests

# Set the URL you want to scrape from
URL = 'https://api-global.morningstar.com/sal-service/v1/stock/ownership/v1/0P0000OQN8/OwnershipData/mutualfund/20/data'

HEADERS = {
    'Accept':'*/*',
    'Accept-Encoding':    'gzip, deflate, br, zstd',
    'Accept-Language':    'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'Apikey':    'lstzFDEOhfFNMLikKa0am9mgEKLBl49T',
    'Origin':    'https://www.morningstar.com',
    'Priority':    'u=1, i',
    'Referer':    'https://www.morningstar.com/stocks/xnas/tsla/sustainability',
    'Sec-Ch-Ua':    '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
    'Sec-Ch-Ua-Mobile':    '?0',
    'Sec-Ch-Ua-Platform':    "Windows",
    'Sec-Fetch-Dest':    'empty',
    'Sec-Fetch-Mode':    'cors',
    'Sec-Fetch-Site':    'same-site',
    'User-Agent':    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}

PAYLOAD = {
    'languageId': 'en',
    'locale': 'en',
    'clientId': 'MDC',
    'component': 'sal-ownership',
    'version': '4.30.0'
}

session = requests.Session()

response = session.get(URL,params=PAYLOAD, headers=HEADERS)
msg = response.json()
pd.DataFrame(msg['rows'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\Thomas\VS\MorningSun\env\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %% [markdown]
# ## GET Markert data

# %%
"""
website_url: https://www.morningstar.com/markets
api_url:  https://www.morningstar.com/api/v2/stocks/xnas/tsla/quote
=>
Comments:
=>
"""
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://www.morningstar.com/api/v2/stocks/xnas/tsla/quote'

HEADERS = {
    'accept': 'application/json, text/plain, */*',
    # 'Authorization':'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik1EY3hOemRHTnpGRFJrSTRPRGswTmtaRU1FSkdOekl5TXpORFJrUTROemd6TWtOR016bEdOdyJ9.....wJCqi9o8HUh0qUnmbAEm5OCuOqfiaiXX13fZhgiZiUVLwqMeceOfgd5ifPkB1lLSkQz9Rc_Bh5SGIK_PXlcFAzYAxHeKcFz0oGjaePIeuDQpqsZ9k-fEDlOHGTQa-uACToVIriZMP6KLewckpfYrVdqL3j6qz1p2jRNLBzd_10-A3x8KHXeMk4CgMIYPIN5Qx3s9LTXELiiOZGRe2uaOeoDBOQTwbXF1PtISV_CWG8BqvHTMzvVKQbAeLM-F_qkQRGKvifRoZshKWPtCCxhaUdRBauXak6-1ahvNdOhHHRzYht-U8BY8waTmR2gkCX29zpFlIdbG4WUMAKsUZgwT5w',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}

session = requests.Session()

response = session.get(URL, headers=HEADERS)

msg = response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\Thomas\VS\MorningSun\env\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %% [markdown]
# ## API - Exchange Info

# %%
"""
website_url: https://www.morningstar.fr/fr/markets/default.aspx
api_url:  https://quotespeed.morningstar.com/service/queryPermission
=>
Comments:
=>
"""

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://quotespeed.morningstar.com/service/queryPermission'

HEADERS = {
    'accept': 'application/json, text/plain, */*',
    # 'Authorization':'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik1EY3hOemRHTnpGRFJrSTRPRGswTmtaRU1FSkdOekl5TXpORFJrUTROemd6TWtOR016bEdOdyJ9.....wJCqi9o8HUh0qUnmbAEm5OCuOqfiaiXX13fZhgiZiUVLwqMeceOfgd5ifPkB1lLSkQz9Rc_Bh5SGIK_PXlcFAzYAxHeKcFz0oGjaePIeuDQpqsZ9k-fEDlOHGTQa-uACToVIriZMP6KLewckpfYrVdqL3j6qz1p2jRNLBzd_10-A3x8KHXeMk4CgMIYPIN5Qx3s9LTXELiiOZGRe2uaOeoDBOQTwbXF1PtISV_CWG8BqvHTMzvVKQbAeLM-F_qkQRGKvifRoZshKWPtCCxhaUdRBauXak6-1ahvNdOhHHRzYht-U8BY8waTmR2gkCX29zpFlIdbG4WUMAKsUZgwT5w',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}


PAYLOAD = {
    'fields': '1,2,4,16,32,64,1024,2048,4096',
    'instid': 'EURTL',
    'sdkver': '2.62.9',
    'productType': 'sdk',
    'sessionId': '2F88466E348F15BDA66D47C6E1A6B9F0',
    '_': '1718748495056'
}

session = requests.Session()

response = session.get(URL,params=PAYLOAD, headers=HEADERS)

msg = response.json()
pd.DataFrame(msg["attachment"]["ExchangeInfo"]).transpose().reset_index().drop(columns="index")
# Out:
#     micCode delayMinute          timezone              name         shortName  \
# 0      RTSX          15     Europe/Moscow              RTSX              RTSX
# 1      XPET          -1     Europe/Moscow  Saint Petersburg  Saint Petersburg
# 2      XNGO          15        Asia/Tokyo            Nagoya            Nagoya
# 3      MISX          15     Europe/Moscow              MISX              MISX
# 4      XBOT          -1   Africa/Gaborone          Botswana          Botswana
# ..      ...         ...               ...               ...               ...
# 285    XSFA          15  America/New_York              XSFA              XSFA
# 286    XBSE          15  Europe/Bucharest         Bucharest         Bucharest
# 287    ROCO          15       Asia/Taipei            Taipei            Taipei
# 288    XZAG          15   Europe/Sarajevo            Balkan            Balkan
# 289    BCXE          15      Europe/Paris         Cboe BXTR         Cboe BXTR
#
# ...

# %% [markdown]
# ## TITLE

# %%
"""
website_url: 
api_url:  
=>
Comments:
=>
"""
import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://www.us-api.morningstar.com/sal/sal-service/stock/realTime/v3/0P000000GY/data'

HEADERS = {
    'Accept':'*/*',
    'Accept-Encoding':'gzip, deflate, br, zstd',
    'Accept-Language':'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'Authorization':'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik1EY3hOemRHTnpGRFJrSTRPRGswTmtaRU1FSkdOekl5TXpORFJrUTROemd6TWtOR016bEdOdyJ9.....YxeJmJZGcN7JwxUu2ITcYRIco98nimJm-Do60JKI5VeP5-VCVTV3ch7gUemnxpztgw9z7ATPXEpiZGpEt5ppNsjdVzT9MDVTcHRbeW74VljLiQ_UgzDplyb1LKdlPWLeIKB8wywLHErhuzdT6klj1OEQ5DpwzbFtIs9Wte1pw8qBw4U3YStS1dFjqmyyIiT7N_sQ6yxqfrkNKZ58f-4EQWVisAl_89dj2AHxZCpb99vFVbyjm85HbOxLaycP_QSjr1RzbRCBmUL8TU4vmSTRREgXOlrM2p8meERxv5pRk8ZnFNgBoy3N_xpRtdfLvuJLlqtnd0k-BD6KRMj6qVOirw',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
    'Cache-Control':    'no-cache, no-store, must-revalidate',
    'Credentials':    'omit',
    'Origin':    'https://www.morningstar.ca',
    'Priority':    'u=1, i',
    'Referer':    'https://www.morningstar.ca/ca/report/stocks/quote.aspx?t=0P000000GY&lang=en-CA'
}

PAYLOAD = {
    'languageId': 'en',
    # 'random': '0.04056044847466067',
    'locale': 'en',
    'clientId': 'MDC_intl',
    'component': 'sal-components-quote',
    'version': '3.60.0'
}

session = requests.Session()

response = session.get(URL,params=PAYLOAD, headers=HEADERS)

response
# Out:
# <Response [401]>

# %% [markdown]
# ## TITLE

# %%
"""
website_url: 
api_url:  
=>
Comments:
=>
"""

import requests

# Define the request URL
url = "https://api-global.morningstar.com/sal-service/v1/stock/header/v2/data/0P000000B7/securityInfo"
       

# Define the headers
headers = {
    'Accept': '*/*',
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Accept-Language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'Origin': 'https://www.morningstar.com.au',
    'Referer': 'https://www.morningstar.com.au/',
    'Sec-Ch-Ua': '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
    'Sec-Ch-Ua-Mobile': '?0',
    'Sec-Ch-Ua-Platform': '"Windows"',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'cross-site',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
    'X-Api-Realtime-E': 'eyJlbmMiOiJBMTI4R0NNIiwiYWxnIjoiUlNBLU9BRVAifQ.1E4oJB3HCtJ2PdjKIIZICy5ezgGD2CykvEXGcogbPOlg_A41fdjqwbj9a8wSutGt14Cyvts7e5n9MgtHb4KFQ7D6ou1jJu7O12M-O35vJSHWJqW4Co7pPqIf6U7-V3_hMcuu1RNRwrtFL9ic47obcJcZdVWx1TxrQjl0ouYnAIc.Hl4r5ODE4AWxcugW.-st5MrpSB660aH9VrqiGow1UHcGGfGMOFRHbMCU3mw1VGwox5JZQkI-_-Bv-8wxrxLxJbRt8QUjI1TcHD-pfAQ7XKlRjh8Q1WxM9PRMEU7mSQ4x5R8LShijyErCFTIUMMGSuz8caAk18JowkpGOcBaSCvqEO8ZlzJs1qjmH9VtrRiFiQItaQvzdSUcEYFYiEEIEMn4Ay9d9Fz69zKqwVZqUqyQWZBBVDM2MOzZI.v3Du6IgztOU7b3FlWHdpyA',
    'X-Api-Requestid': '02be7774-e78a-85ef-5cd5-0e2936745777',
    'X-Sal-Contenttype': 'e7FDDltrTy+tA2HnLovvGL0LFMwT+KkEptGju5wXVTU='
}

# Make the GET request

response = session.get(URL,params=PAYLOAD, headers=HEADERS)

# Check if the request was successful
if response.status_code == 200:
    # Print the response content
    print(response.json())
else:
    print(f"Request failed with status code {response.status_code}")
# Out:
# Request failed with status code 404

# %% [markdown]
# ## TITLE

# %%
"""
website_url: 
api_url:  
=>
Comments:
=>
"""
import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://www.morningstar.com/api/v2/stocks/details/LU0011963245USD'

HEADERS = {
    'Accept':'*/*',
    "Content-Type": "application/json",
    'Accept-Encoding':'gzip, deflate, br, zstd',
    'Accept-Language':'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'Authorization':'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik1EY3hOemRHTnpGRFJrSTRPRGswTmtaRU1FSkdOekl5TXpORFJrUTROemd6TWtOR016bEdOdyJ9.....Hj229brtbPTMR2t2lwicBLuzd2FUN2BqxoZPHUrf_AMmnRf1ejnm-6ha86ShulBlkUxdLRliDj7jg_Ax5sHWDD7zj7jNvjqaur2wICuzKXrjZO5iCrJzkr247VKmJxkfyTsW6ZUnjf1X83le6FEJ0iUcRdY_mVzCTowg-OBDkTFte2RHNcRMFX1824MGTEgN9cqGkA9NEEdJtvlmNR02WPnuroiom9HPnQf427CWwrmpdd1h0VwxIzQDteXiLXGchIxUZ3FgmbJZDUCQn02jhG0el83IjEiZIhN6yQuzc_lzGfmkD0-Yvfl8Dfy3qLCpQnaEtLX0gjeFjb1N8i3S9A',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
    'Cache-Control':    'no-cache, no-store, must-revalidate',
}

PAYLOAD = {
    'id': 'LU0011963245USD',
}

# Make the GET request
session = requests.Session()
# response = requests.get(URL, headers=HEADERS, params=PAYLOAD)
response = requests.get(URL, headers=HEADERS)

print(response)
# Out:
# <Response [404]>

# %% [markdown]
# ## TITLE

# %%
"""
website_url: https://www.morningstar.com/stocks/xnas/nvda/quote
api_url:  https://www.morningstar.com/api/v2/stores/realtime/quotes
=>
Comments:
=> The url can be used to get company information
"""

import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://www.morningstar.com/api/v2/stores/realtime/quotes'

HEADERS = {
    'Accept':'*/*',
    "Content-Type": "application/json",
    'Accept-Encoding':'gzip, deflate, br, zstd',
    'Accept-Language':'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'Cookie':'_cb=CHQE1OH0npskmPmL; mid=7136847794596326555; msession=29fc031e-3dc2-45fa-92d6-c062d4a90e47.88eae3068a44b61d77de9d7cde0af5c88f95a48da7d5e117c29d68a0ec966271; ELOQUA=GUID=7E6FFEC9AE384AF6B953EFE8F77580F4; _ga_ZHP6HH58B1=GS1.1.1708771783.1.0.1708771785.58.0.0; _gcl_au=1.1.848195055.1718742360; _gd_svisitor=355a16020d310000a0b1526347010000f06d0a00; _an_uid=9128226608692305453; _gd_visitor=c2265828-5d85-47b6-8f3c-465cd2c35358; ELQCOUNTRY=FR; _uetvid=97394690a6dc11ed88aad9eefd0db656; optimizelyEndUserId=oeu1718750700294r0.6385944550700966; OptanonConsent=isGpcEnabled=0&datestamp=Sat+Jun+22+2024+15%3A25%3A19+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202306.1.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=4abfe687-a1f5-439c-99ce-cb83973277f0&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0003%3A0%2CC0002%3A0%2CC0004%3A0&AwaitingReconsent=false; _ga_LMTVSGTMT2=GS1.1.1719062675.1.1.1719063653.0.0.0; _ga_SW6G2BFREG=GS1.1.1719062675.1.1.1719063653.0.0.0; _ga_DLZP83KFTR=GS1.1.1719062675.1.1.1719063653.0.0.0; mbuddy=eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXSyIsImtpZCI6IjE2NjYwMjExMjkifQ.eyJzZXNzaW9uIjoiMjlmYzAzMWUtM2RjMi00NWZhLTkyZDYtYzA2MmQ0YTkwZTQ3Ljg4ZWFlMzA2OGE0NGI2MWQ3N2RlOWQ3Y2RlMGFmNWM4OGY5NWE0OGRhN2Q1ZTExN2MyOWQ2OGEwZWM5NjYyNzEiLCJpYXQiOjE3MTkxNTc5NjMsImlzcyI6Imh0dHBzOi8vaW52ZXN0b3IubW9ybmluZ3N0YXIuY29tIiwiZXhwIjoxNzE5MTU4MjYzfQ.ZQBWGVMFGECwK81TFm6CUSHl-g_4EsR-la015Svg_HS6bIY0Qhyv8VDSD_wTYk28nHeT7GDPRcs-KiNvVSF8iGpJZ10641xh8nlQ3s2M8pJ2pJRtnVsQ-eY-01grjADu-1HeShuWmk2Z1MzLc13LO4fyymPivCPRcMvZiFVVBhaX2WCCYDC_PEZg8kxP0y3leRhzvwBwa8GbsAlhBRVRzXbl2wJy9RRlLA3zoQ1jnMWqvXkJpD_TgloY-IjLr4uvNr6l3KS6yFZY1Dn_hVZXEhjKIDPsqIR2L21p4ZJ7V9RU4gvDo_msbujVtXLk0onn-hn-wQ2GIZxIEjyCYHlWcA; _t_tests=eyI2VDFVQmg4VHhFS29YIjp7ImNob3NlblZhcmlhbnQiOiJCIiwic3BlY2lmaWNMb2NhdGlvbiI6WyJ1TXViSyJdfSwiVk5zVlpzN2wyR0l5MCI6eyJjaG9zZW5WYXJpYW50IjoiQiIsInNwZWNpZmljTG9jYXRpb24iOlsibGt5VUciXX0sImxpZnRfZXhwIjoibSJ9; _gid=GA1.2.883470884.1719157982; _dc_gtm_UA-141496933-1=1; _cb_svref=external; _gd_session=7dcd88d1-a176-48e8-8e90-3b1331c3d8c1; _ga=GA1.2.1026723484.1708771784; _chartbeat2=.1675770197818.1719157984937.0000000000110011.DsbmO5BjVt1pC25CwzCgdVW9DpE2kF.2; _chartbeat5=; _chartbeat4=t=BhInNoDgj3RCBIdR1mB2vkZdXby5S&E=3&x=500&c=0.14&y=6433&w=911; _ga_G8C0R44VCK=GS1.1.1719157982.4.1.1719157993.0.0.0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
}

PAYLOAD = {
    'securities': 'xnas:nvda',
}

# Make the GET request
session = requests.Session()
response = requests.get(URL, headers=HEADERS, params=PAYLOAD)


pd.DataFrame(response.json())
# Out:
#                                                              xnas:nvda  \
# postMarketNetChange  {'value': 0.42, 'properties': {'currency': {'v...
# preMarketNetChange   {'value': -3.67, 'properties': {'currency': {'...
# openPrice            {'value': 127.12, 'properties': {'currency': {...
# tradingStatus        {'value': 'Closed', 'properties': {'exchange':...
# lowPrice             {'value': 124.3, 'properties': {'currency': {'...
# highPrice            {'value': 130.63, 'properties': {'currency': {...
# percentNetChange     {'value': -3.2191, 'properties': {'date': {'va...
# preMarketPrice       {'value': 127.11, 'properties': {'currency': {...
# netChange            {'value': -4.21, 'properties': {'date': {'valu...
# askPrice             {'value': 127, 'properties': {'date': {'value'...
# marketCap            {'value': 3113412143142.9, 'properties': {'cur...
# ticker                             {'value': 'NVDA', 'properties': {}}
# ...

# %% [markdown]
# ## TITLE

# %%
"""
website_url: https://www.morningstar.com/stocks/xnas/nvda/quote
api_url:  https://www.morningstar.com/api/v2/stores/realtime/quotes
=>
Comments:
=> The url can be used to get timeseries with approximatly 5min intervals. 
"""

import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://www.morningstar.com/api/v2/stores/realtime/timeseries'

HEADERS = {
    'Accept':'*/*',
    "Content-Type": "application/json",
    'Accept-Encoding':'gzip, deflate, br, zstd',
    'Accept-Language':'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'Cookie':'_cb=CHQE1OH0npskmPmL; mid=7136847794596326555; msession=29fc031e-3dc2-45fa-92d6-c062d4a90e47.88eae3068a44b61d77de9d7cde0af5c88f95a48da7d5e117c29d68a0ec966271; ELOQUA=GUID=7E6FFEC9AE384AF6B953EFE8F77580F4; _ga_ZHP6HH58B1=GS1.1.1708771783.1.0.1708771785.58.0.0; _gcl_au=1.1.848195055.1718742360; _gd_svisitor=355a16020d310000a0b1526347010000f06d0a00; _an_uid=9128226608692305453; _gd_visitor=c2265828-5d85-47b6-8f3c-465cd2c35358; ELQCOUNTRY=FR; _uetvid=97394690a6dc11ed88aad9eefd0db656; optimizelyEndUserId=oeu1718750700294r0.6385944550700966; OptanonConsent=isGpcEnabled=0&datestamp=Sat+Jun+22+2024+15%3A25%3A19+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202306.1.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=4abfe687-a1f5-439c-99ce-cb83973277f0&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0003%3A0%2CC0002%3A0%2CC0004%3A0&AwaitingReconsent=false; _ga_LMTVSGTMT2=GS1.1.1719062675.1.1.1719063653.0.0.0; _ga_SW6G2BFREG=GS1.1.1719062675.1.1.1719063653.0.0.0; _ga_DLZP83KFTR=GS1.1.1719062675.1.1.1719063653.0.0.0; mbuddy=eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXSyIsImtpZCI6IjE2NjYwMjExMjkifQ.eyJzZXNzaW9uIjoiMjlmYzAzMWUtM2RjMi00NWZhLTkyZDYtYzA2MmQ0YTkwZTQ3Ljg4ZWFlMzA2OGE0NGI2MWQ3N2RlOWQ3Y2RlMGFmNWM4OGY5NWE0OGRhN2Q1ZTExN2MyOWQ2OGEwZWM5NjYyNzEiLCJpYXQiOjE3MTkxNTc5NjMsImlzcyI6Imh0dHBzOi8vaW52ZXN0b3IubW9ybmluZ3N0YXIuY29tIiwiZXhwIjoxNzE5MTU4MjYzfQ.ZQBWGVMFGECwK81TFm6CUSHl-g_4EsR-la015Svg_HS6bIY0Qhyv8VDSD_wTYk28nHeT7GDPRcs-KiNvVSF8iGpJZ10641xh8nlQ3s2M8pJ2pJRtnVsQ-eY-01grjADu-1HeShuWmk2Z1MzLc13LO4fyymPivCPRcMvZiFVVBhaX2WCCYDC_PEZg8kxP0y3leRhzvwBwa8GbsAlhBRVRzXbl2wJy9RRlLA3zoQ1jnMWqvXkJpD_TgloY-IjLr4uvNr6l3KS6yFZY1Dn_hVZXEhjKIDPsqIR2L21p4ZJ7V9RU4gvDo_msbujVtXLk0onn-hn-wQ2GIZxIEjyCYHlWcA; _t_tests=eyI2VDFVQmg4VHhFS29YIjp7ImNob3NlblZhcmlhbnQiOiJCIiwic3BlY2lmaWNMb2NhdGlvbiI6WyJ1TXViSyJdfSwiVk5zVlpzN2wyR0l5MCI6eyJjaG9zZW5WYXJpYW50IjoiQiIsInNwZWNpZmljTG9jYXRpb24iOlsibGt5VUciXX0sImxpZnRfZXhwIjoibSJ9; _gid=GA1.2.883470884.1719157982; _dc_gtm_UA-141496933-1=1; _cb_svref=external; _gd_session=7dcd88d1-a176-48e8-8e90-3b1331c3d8c1; _ga=GA1.2.1026723484.1708771784; _chartbeat2=.1675770197818.1719157984937.0000000000110011.DsbmO5BjVt1pC25CwzCgdVW9DpE2kF.2; _chartbeat5=; _chartbeat4=t=BhInNoDgj3RCBIdR1mB2vkZdXby5S&E=3&x=500&c=0.14&y=6433&w=911; _ga_G8C0R44VCK=GS1.1.1719157982.4.1.1719157993.0.0.0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
}

PAYLOAD = {
    'securities': 'xmun:HH20',
}

# Make the GET request
session = requests.Session()
response = requests.get(URL, headers=HEADERS, params=PAYLOAD)
msg = response.json()
# pd.DataFrame(msg['xnas:nvda']['intervals'])
msg
# Out:
# {'xmun:HH20': None}

# %% [markdown]
# ## TITLE

# %%
"""
website_url: https://www.morningstar.com/stocks/xnas/nvda/quote
api_url:  https://www.morningstar.com/api/v2/stores/realtime/quotes
=>
Comments:
=> The url can be used to get timeseries with approximatly 5min intervals. 
"""

import requests
from urllib.parse import unquote
import pandas as pd

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Cookies

URL = r'https://global.morningstar.com/fr/investissements/etf/0P0001U0G4/graphique'

HEADERS = {
    'Accept':'*/*',
    "Content-Type": "application/json",
    'Accept-Encoding':'gzip, deflate, br, zstd',
    'Accept-Language':'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    # 'Cookie':'_cb=CHQE1OH0npskmPmL; mid=7136847794596326555; msession=29fc031e-3dc2-45fa-92d6-c062d4a90e47.88eae3068a44b61d77de9d7cde0af5c88f95a48da7d5e117c29d68a0ec966271; ELOQUA=GUID=7E6FFEC9AE384AF6B953EFE8F77580F4; _ga_ZHP6HH58B1=GS1.1.1708771783.1.0.1708771785.58.0.0; _gcl_au=1.1.848195055.1718742360; _gd_svisitor=355a16020d310000a0b1526347010000f06d0a00; _an_uid=9128226608692305453; _gd_visitor=c2265828-5d85-47b6-8f3c-465cd2c35358; ELQCOUNTRY=FR; _uetvid=97394690a6dc11ed88aad9eefd0db656; optimizelyEndUserId=oeu1718750700294r0.6385944550700966; OptanonConsent=isGpcEnabled=0&datestamp=Sat+Jun+22+2024+15%3A25%3A19+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202306.1.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=4abfe687-a1f5-439c-99ce-cb83973277f0&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0003%3A0%2CC0002%3A0%2CC0004%3A0&AwaitingReconsent=false; _ga_LMTVSGTMT2=GS1.1.1719062675.1.1.1719063653.0.0.0; _ga_SW6G2BFREG=GS1.1.1719062675.1.1.1719063653.0.0.0; _ga_DLZP83KFTR=GS1.1.1719062675.1.1.1719063653.0.0.0; mbuddy=eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXSyIsImtpZCI6IjE2NjYwMjExMjkifQ.eyJzZXNzaW9uIjoiMjlmYzAzMWUtM2RjMi00NWZhLTkyZDYtYzA2MmQ0YTkwZTQ3Ljg4ZWFlMzA2OGE0NGI2MWQ3N2RlOWQ3Y2RlMGFmNWM4OGY5NWE0OGRhN2Q1ZTExN2MyOWQ2OGEwZWM5NjYyNzEiLCJpYXQiOjE3MTkxNTc5NjMsImlzcyI6Imh0dHBzOi8vaW52ZXN0b3IubW9ybmluZ3N0YXIuY29tIiwiZXhwIjoxNzE5MTU4MjYzfQ.ZQBWGVMFGECwK81TFm6CUSHl-g_4EsR-la015Svg_HS6bIY0Qhyv8VDSD_wTYk28nHeT7GDPRcs-KiNvVSF8iGpJZ10641xh8nlQ3s2M8pJ2pJRtnVsQ-eY-01grjADu-1HeShuWmk2Z1MzLc13LO4fyymPivCPRcMvZiFVVBhaX2WCCYDC_PEZg8kxP0y3leRhzvwBwa8GbsAlhBRVRzXbl2wJy9RRlLA3zoQ1jnMWqvXkJpD_TgloY-IjLr4uvNr6l3KS6yFZY1Dn_hVZXEhjKIDPsqIR2L21p4ZJ7V9RU4gvDo_msbujVtXLk0onn-hn-wQ2GIZxIEjyCYHlWcA; _t_tests=eyI2VDFVQmg4VHhFS29YIjp7ImNob3NlblZhcmlhbnQiOiJCIiwic3BlY2lmaWNMb2NhdGlvbiI6WyJ1TXViSyJdfSwiVk5zVlpzN2wyR0l5MCI6eyJjaG9zZW5WYXJpYW50IjoiQiIsInNwZWNpZmljTG9jYXRpb24iOlsibGt5VUciXX0sImxpZnRfZXhwIjoibSJ9; _gid=GA1.2.883470884.1719157982; _dc_gtm_UA-141496933-1=1; _cb_svref=external; _gd_session=7dcd88d1-a176-48e8-8e90-3b1331c3d8c1; _ga=GA1.2.1026723484.1708771784; _chartbeat2=.1675770197818.1719157984937.0000000000110011.DsbmO5BjVt1pC25CwzCgdVW9DpE2kF.2; _chartbeat5=; _chartbeat4=t=BhInNoDgj3RCBIdR1mB2vkZdXby5S&E=3&x=500&c=0.14&y=6433&w=911; _ga_G8C0R44VCK=GS1.1.1719157982.4.1.1719157993.0.0.0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
}

# Make the GET request
session = requests.Session()
response = requests.get(URL, headers=HEADERS, params=PAYLOAD)
msg = response.json()
# pd.DataFrame(msg['xnas:nvda']['intervals'])
msg
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\Thomas\VS\MorningSun\env\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
"""
website_url: https://www.morningstar.com/stocks/xnas/nvda/quote
api_url:  https://www.morningstar.com/api/v2/stores/realtime/quotes
=>
Comments:
=> The url can be used to get timeseries with approximatly 5min intervals. 
"""

import requests
import re
import pandas as pd

ticker = "F000016GZH"

# 1. GET KeyApi 

URL = "https://global.morningstar.com/assets/quotes/1.0.36/sal-components.umd.min.3594.js"

HEADERS = {
    "accept": "*/*",
    "accept-encoding": "gzip, deflate, br",  # le serveur renvoie Brotli
    "accept-language": "fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36",
}

resp = requests.get(URL, headers=HEADERS)
raw = resp.text
match = re.search(r'keyApigee\s*[:=]\s*"([^"]+)"', raw)
api_key = match.group(1)


# 2. Call MorningStar Api

# url = "https://api-global.morningstar.com/sal-service/v1/etf/parent/mstarRating/StarRatingFundAsc/F00000IRIL/data"
URL = f"https://api-global.morningstar.com/sal-service/v1/etf/factorProfile/{ticker}/data"

PARAMS = {
    "languageId": "fr",
    "locale": "fr",
    "clientId": "MDC",
    "benchmarkId": "prospectus_primary",
    "component": "sal-mip-star-rating-breakdown",
    "version": "4.69.0"
}

HEADERS = {
    "accept": "*/*",
    "accept-encoding": "gzip, deflate, br",
    "accept-language": "fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7",
    "apikey": f"{api_key}",
    "cache-control": "no-cache",
    "origin": "https://global.morningstar.com",
    "pragma": "no-cache",
    "sec-ch-ua": '"Not;A=Brand";v="99", "Google Chrome";v="139", "Chromium";v="139"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36",
}

response = requests.get(URL, headers=HEADERS, params=PARAMS)
data = response.json()
data
# Out:
# {'name': 'Amundi Core Nasdaq-100 Swap ETF € H Acc',
#  'categoryId': 'EUCA000539',
#  'categoryName': 'Autres actions',
#  'indexId': 'F00000UMIL',
#  'indexName': 'NASDAQ 100 NR USD',
#  'indexEffectiveDate': '2025-08-31',
#  'categoryEffectiveDate': '2025-08-31',
#  'ticker': 'BUNH',
#  'id': '0P0001LOPQ',
#  'effectiveDate': '2025-08-31',
#  'factors': {'style': {'categoryAvg': 46.457153,
#    'indexAvg': 23.190702,
#    'percentile': 22.556409,
#    'historicRange': [{'year': '1', 'min': 22.556409, 'max': 26.75108},
#     {'year': '3', 'min': 11.406514, 'max': 26.75108},
#     {'year': '5', 'min': 11.395045, 'max': 26.75108}]},
#   'yield': {'categoryAvg': 47.706615,
#    'indexAvg': 79.041978,
#    'percentile': 79.523276,
#    'historicRange': [{'year': '1', 'min': 74.2167, 'max': 79.523276},
#     {'year': '3', 'min': 64.929397, 'max': 79.523276},
#     {'year': '5', 'min': 61.862459, 'max': 79.523276}]},
#   'quality': {'categoryAvg': 43.921574,
#    'indexAvg': 9.526304,
# ...

# %%
"""
website_url: https://www.morningstar.com/stocks/xnas/nvda/quote
api_url:  https://www.morningstar.com/api/v2/stores/realtime/quotes
=>
Comments:
=> The url can be used to get timeseries with approximatly 5min intervals. 
"""

import requests
import re
import pandas as pd

ticker = "F00000ZD4T"

# 1. GET KeyApi 

URL = "https://global.morningstar.com/assets/quotes/1.0.36/sal-components.umd.min.3594.js"

HEADERS = {
    "accept": "*/*",
    "accept-encoding": "gzip, deflate, br",  # le serveur renvoie Brotli
    "accept-language": "fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36",
}

resp = requests.get(URL, headers=HEADERS)
raw = resp.text
match = re.search(r'keyApigee\s*[:=]\s*"([^"]+)"', raw)
api_key = match.group(1)


# 2. Call MorningStar Api

# url = "https://api-global.morningstar.com/sal-service/v1/etf/parent/mstarRating/StarRatingFundAsc/F00000IRIL/data"
# URL = rf"https://api-global.morningstar.com/sal-service/v1/stock/keyMetrics/summary/{ticker}"
# URL=rf"https://api-global.morningstar.com/sal-service/v1/etf/morningstarTake/investmentStrategy/{ticker}/data"
URL= rf"https://api-global.morningstar.com/sal-service/v1/etf/esgRisk/{ticker}/data"

PARAMS = {
    "reportType":"A",
    "languageId": "eg",
    "locale": "eg",
    "clientId": "MDC",
    "benchmarkId": "prospectus_primary",
    "component": "sal-mip-esg-risk",  # sal-eqsv-key-metrics-financial-summary , sal-mip-star-rating-breakdown ; sal-equity-financials ;sal-mip-strategy
    "version": "4.69.0"
}

HEADERS = {
    "accept": "*/*",
    "accept-encoding": "gzip, deflate, br",
    "accept-language": "fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7",
    "apikey": f"{api_key}",
    "cache-control": "no-cache",
    "origin": "https://global.morningstar.com",
    "pragma": "no-cache",
    "sec-ch-ua": '"Not;A=Brand";v="99", "Google Chrome";v="139", "Chromium";v="139"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36",
}

response = requests.get(URL, headers=HEADERS, params=PARAMS)
data = response.json()
data
# data["incomeStatementList"]
# data["balanceSheetList"]
# data["cashFlowList"]
# pd.DataFrame(data["cashFlowList"]["dataList"])
# Out:
# {'sustainabilityFundQuintile': 3,
#  'fundHistoryAvgSustainabilityScore': 22.53193,
#  'fundSustainabilityScore': 22.56,
#  'historicalSustainabilityScoreGlobalCategoryAverage': 22.08322,
#  'historicalSovereignSustainabilityScore': None,
#  'portfolioSovereignSustainabilityScore': None,
#  'historicalSovereignSustainabilityCategoryAverage': 14.14016,
#  'percentAUMCoveredESG': 99.74534,
#  'sovereignSustainabilityRatingPercentOfEligiblePortfolioCovered': None,
#  'globalCategoryName': 'Global Emerging Markets Equity',
#  'categoryRankDate': '2025-08-31T00:00:00.000',
#  'portfolioDateSustainabilityRating': '2025-08-31T05:00:00.000',
#  'categoryId': 'EUCA000507',
#  'portfolioDate': '2025-08-31T00:00:00.000',
#  'carbon': {'carbonPortfolioCoveragePct': None,
#   'carbonRiskScore': None,
#   'carbonRiskScoreCategoryAverage': '8.52498',
#   'carbonRiskScoreCategoryHigh': '20.30661',
#   'carbonRiskScoreCategoryLow': '3.36701',
# ...

# %%
import requests
from urllib.parse import unquote
import pandas as pd
import re

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Get Token

URL = r'https://global.morningstar.com/fr/investissements/etf/0P0001U0G4/graphique'

HEADERS = {
    'Accept': '*/*',
    "Content-Type": "application/json",
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Accept-Language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
}

# Récupération de la page HTML
response = requests.get(URL, headers=HEADERS)
msg = response.text

# Regex pour capturer maasToken = "xxxxxx"
match = re.search(r'maasToken\s*[:=]\s*"([^"]+)"', msg)

if match:
    token = match.group(1)
    print("✅ maasToken trouvé:")
    print(token)
else:
    print("❌ maasToken non trouvé dans le HTML brut")
    # Petit debug : afficher un extrait pour vérifier
    print(msg[:500])

URL = r'https://www.us-api.morningstar.com/QS-markets/chartservice/v2/timeseries'

HEADERS = {
    "accept": "application/json, text/plain, */*",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7",
    "authorization": f"Bearer {token}",
    "cache-control": "no-cache",
    "origin": "https://global.morningstar.com",
    "pragma": "no-cache",
    "priority": "u=1, i",
    "referer": "https://global.morningstar.com/fr/investissements/etf/0P0001U0G4/graphique",
    # "sec-ch-ua": "\"Not;A=Brand\";v=\"99\", \"Google Chrome\";v=\"139\", \"Chromium\";v=\"139\"",
    "sec-ch-ua-mobile": "?0",
    # "sec-ch-ua-platform": "\"Windows\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36",
    # "x-api-requestid": "dc94dc2e-9938-430b-ac83-5c7197e7851f"
}


# PAYLOAD = {
#     'query': 'F00000VYXH:totalReturn,nav,dividend',
#     'frequency': 'd',
#     'startDate':'2015-06-30',
#     'endDate':'2025-09-26',
#     'trackMarketData': '3.6.5',
#     'instid': 'DOTCOM'
# }

PAYLOAD = {
    'query': '0P00009WE1:open,high,low,close,volume,previousClose',
    'frequency': 'd',
    'startDate':'1900-01-01',
    'endDate':'2025-09-26',
    'trackMarketData': '3.6.5',
    'instid': 'DOTCOM'
}

session = requests.Session()

response = session.get(URL,params=PAYLOAD, headers=HEADERS)

msg = response.json()

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Proceed Data

data = msg[0]["series"]

df = pd.DataFrame(data)

df

request_id = response.headers.get("x-api-requestid")
print(request_id)
# Out:
# ✅ maasToken trouvé:
# eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik1EY3hOemRHTnpGRFJrSTRPRGswTmtaRU1FSkdOekl5TXpORFJrUTROemd6TWtOR016bEdOdyJ9.....vw0wgF2qzwIlDV4Dltj5aiIASfIpe5sAWM_7UUcDcapQhKuUeZKcaNV_1yUWfZkx0Xji-iMTaX2eH7_hSwL7s05FPA8dR-XtgcXZ-9B7MsezAsNStPzbpjNSO3z86OMoCrwhdKCqBpnZ3xCfeGwY5tkE_4eM77do65m-FymBbG_NLJ0xBcLHQ6L9_Uh3bcKg2l4WktUDxwofbMBYnX2gRHiH64dsUen_NKpVBkDqzyZVjD-sHtoFPz5fYJeGtU9BMDPwKIu7WPw9wY3jOABNZBVI1LOd_S_BTpw1kx6JcTfGRofBJ9Zmt-z2ke_hgEhztekbL_D8s7xjfbcWKt5aRQ
# None

# %%
import requests
from http.cookies import SimpleCookie

URL = 'https://www.morningstar.com/api/v2/stocks/xnas/tsla/news'
HEADERS = {
    'accept': 'application/json, text/plain, */*',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}

session = requests.Session()
response = session.get(URL, headers=HEADERS)

# 1️⃣ Extract raw Set-Cookie headers from the response
set_cookie_header = response.headers.get('Set-Cookie')

print("\n--- Raw Set-Cookie header ---")
print(set_cookie_header)

# 2️⃣ Parse them into structured cookie objects
cookie = SimpleCookie()
if set_cookie_header:
    cookie.load(set_cookie_header)

# 3️⃣ Print each cookie with your preferred formatting
print("\n--- Formatted cookies ---")
for key, morsel in cookie.items():
    formatted = (
        f"{key}={morsel.value}; "
        f"Domain=.morningstar.com; Path=/; Secure; HttpOnly; "
        f"Expires=Sat, 05 Oct 2030 20:10:10 GMT;"
    )
    print(formatted)
# Out:
# --- Raw Set-Cookie header ---
# None
#
# --- Formatted cookies ---

# %%
import requests
URL =  "https://api-global.morningstar.com/sal-service/v1/fund/securityMetaData/F00000ZD4T"
HEADERS = {
    'accept': 'application/json, text/plain, */*',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}
session = requests.Session()
response = session.get(URL, headers=HEADERS)
response.text
# Out:
# '{\n  "message":"Unauthorized",\n  "request_id":"48691e47c22f4f2e3d953f02d772813f"\n}'

# %%
import requests
URL = 'https://www.morningstar.com/api/v2/stocks/xnas/tsla/news'
HEADERS = {
    'accept': 'application/json, text/plain, */*',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}
response = session.get(URL, headers=HEADERS)

# Sometimes requestId is in headers
request_id = response.headers.get("requestid")
print(request_id)
# Out:
# None

# %%
import requests
from urllib.parse import unquote
import pandas as pd
import re

URL = "https://global.morningstar.com/assets/quotes/1.0.36/sal-components.umd.min.3594.js"

HEADERS = {
    "accept": "*/*",
    "accept-encoding": "gzip, deflate, br",  # le serveur renvoie Brotli
    "accept-language": "fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36",
}

resp = requests.get(URL, headers=HEADERS)
raw = resp.text
match = re.search(r'keyApigee\s*[:=]\s*"([^"]+)"', raw)
api_key = match.group(1)

URL = r'ttps://global.morningstar.com/api/v1/en-ca/tools/screener/_data'

HEADERS = {
    "accept": "*/*",
    "accept-encoding": "gzip, deflate, br",
    "accept-language": "fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7",
    "apikey": f"{api_key}",
    "cache-control": "no-cache",
    "origin": "https://global.morningstar.com",
    "pragma": "no-cache",
    "sec-ch-ua": '"Not;A=Brand";v="99", "Google Chrome";v="139", "Chromium";v="139"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36",
}

PARAMS = {
    "query":"(((investmentType = 'EQ'))) AND (exchangeCountry in ('CAN', 'ZWE', 'ZMB', 'ZAF', 'VNM', 'VEN', 'USA', 'URY', 'UKR', 'TZA', 'TUN', 'TUR', 'TWN', 'TTO', 'THA', 'SWZ', 'SWE', 'SVN', 'SVK', 'SRB', 'SGP', 'ARE', 'ARG', 'ARM', 'AUS', 'AUT', 'BEL', 'BGD', 'BGR', 'BHR', 'BIH', 'BMU', 'BOL', 'BRA', 'BWA', 'CHE', 'CHN', 'CHL', 'COL', 'CIV', 'CZE', 'CYP', 'FRA', 'FIN', 'EST', 'ESP', 'EGY', 'ECU', 'DNK', 'DEU', 'SAU', 'RUS', 'ROU', 'QAT', 'PSE', 'PRT', 'POL', 'PHL', 'PER', 'PAN', 'PAK', 'OMN', 'NZL', 'NPL', 'NOR', 'NLD', 'NGA', 'NAM', 'MYS', 'MWI', 'MUS', 'MNE', 'MLT', 'MKD', 'MEX', 'MAR', 'LVA', 'LTU', 'LUX', 'LKA', 'LBN', 'KWT', 'KOR', 'KEN', 'KAZ', 'JPN', 'JOR', 'JAM', 'ITA', 'ISR', 'ISL', 'IRQ', 'IRN', 'IRL', 'IND', 'IDN', 'HUN', 'HRV', 'HKG', 'GRC', 'GHA', 'GBR'))",
    "fields":"name,ticker,sector,industry,stockStyleBox,marketCap,dividendYield[trailing],exchange",
    "page":1,
    "sort":"name:asc"
}

response = requests.get(URL, headers=HEADERS, params=PARAMS)
data = response.json()
data
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# Cell In[3], line 46
#      22 HEADERS = {
#      23     "accept": "*/*",
#      24     "accept-encoding": "gzip, deflate, br",
#    (...)     36     "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36",
#      37 }
#      39 PARAMS = {
# ...

# %%
"""
website_url: https://www.morningstar.com/stocks/xnas/nvda/quote
api_url:  https://www.morningstar.com/api/v2/stores/realtime/quotes
=>
Comments:
=> The url can be used to get timeseries with approximatly 5min intervals. 
"""

import requests
import re
import pandas as pd


# 1. GET KeyApi 

URL = "https://global.morningstar.com/assets/quotes/1.0.36/sal-components.umd.min.3594.js"

HEADERS = {
    "accept": "*/*",
    "accept-encoding": "gzip, deflate, br",  # le serveur renvoie Brotli
    "accept-language": "fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36",
}

resp = requests.get(URL, headers=HEADERS)
raw = resp.text
match = re.search(r'keyApigee\s*[:=]\s*"([^"]+)"', raw)
api_key = match.group(1)


# 2. Call MorningStar Api

# url = "https://api-global.morningstar.com/sal-service/v1/etf/parent/mstarRating/StarRatingFundAsc/F00000IRIL/data"
# URL = rf"https://api-global.morningstar.com/sal-service/v1/stock/keyMetrics/summary/{ticker}"
# URL=rf"https://api-global.morningstar.com/sal-service/v1/etf/morningstarTake/investmentStrategy/{ticker}/data"
URL= "https://www.morningstar.com/api/v2/markets/calendar"

PARAMS = {
    "date":"2025-10-08",
    "category": "earnings",
}

HEADERS = {
    "accept": "application/json, text/plain, */*",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7",
    # "apikey": f"{api_key}",
    "cache-control": "no-cache",
    "refer": "https://www.morningstar.com/markets/calendar?date=2025-10-07&category=economic-releases",
    "pragma": "no-cache",
    "sec-ch-ua": '"Not;A=Brand";v="99", "Google Chrome";v="139", "Chromium";v="139"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36",
    "set-cookie":"mbuddy=eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXSyIsImtpZCI6IjE2NjYwMjExMjkifQ.eyJzZXNzaW9uIjoiYTkzZTkzMWQtZDk5MC00N2Y0LTgxZTctNDdhZTM3YmZhYzBjLjkxYTAyMzljNTg4NTAwZTJhY2ExOThlMGJmYWY5N2FhNDg1NGVhNzE4MjJhZDBiOTM4NjJkNDIwNTA3OWQyM2MiLCJpYXQiOjE3NjAyMDA4MDUsImlzcyI6Imh0dHBzOi8vaW52ZXN0b3IubW9ybmluZ3N0YXIuY29tIiwiZXhwIjoxNzYwMjAxMTA1fQ.P32YmNH9WqfqGhgXuKn5XW6DF1aHgWAJh1GJNlyASO5ncRqxYeUZFa_xTgG7qaVVD90lBrF6tdGiTcECWTgcqZGI9TrgRt6_59d_FOx88k1rNH16Ko90ayz0IYEN_eEAXkDbjWL1nUF-1CJNToGwGzN80dLLZWPVgdRQ4rR3ahsRU5XMYDDl0WvfBa9BviLbnRb1QpgBdJej-zohxkXVrjoO_oWk0JDGXMwWVnKPUlbID2xtwPuke_VIVJEyM6f0r78BTULNaUmhPvL_-tBAvzEHrs-ozn2v3FgKp6agRmm-NQIiYc-VFPP1E9hP0FFtwOTK7r3fHcAGM1J8al5wOg; Domain=.morningstar.com; Path=/; Secure; HttpOnly;",
    "set-cookie":"msession=a93e931d-d990-47f4-81e7-47ae37bfac0c.91a0239c588500e2aca198e0bfaf97aa4854ea71822ad0b93862d4205079d23c; Domain=.morningstar.com; Path=/; Secure; HttpOnly; Expires=Fri, 11 Oct 2030 16:41:34 GMT;",
    # "x-aws-waf-token":"8ed006e6-52cb-4d54-a47a-31561bb8ed64:DAoAlMp1PwcjAAAA:"
}

response = requests.get(URL, headers=HEADERS, params=PARAMS)
data = response.json()
data
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\Thomas\VS\MorningSun\env\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...
